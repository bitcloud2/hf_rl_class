# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - SpacesInvadersNoFrameskip-v4
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 500**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# !apt install -y python-opengl
# !apt install -y ffmpeg
# !apt install -y xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python2
#   python2-minimal python2.7 python2.7-minimal
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc python2.7-doc binfmt-support
# The following NEW packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python-opengl
#   python2 python2-minimal python2.7 python2.7-minimal
# 0 upgraded, 8 newly installed, 0 to remove and 78 not upgraded.
# Need to get 4,298 kB of archives.
# After this operation, 21.9 MB of additional disk space will be used.
# Get:1 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libpython2.7-minimal amd64 2.7.18-1~20.04.3 [336 kB]
# Get:2 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python2.7-minimal amd64 2.7.18-1~20.04.3 [1,280 kB]
# Get:3 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:4 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libpython2.7-stdlib amd64 2.7.18-1~20.04.3 [1,888 kB]
# Get:5 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 python2.7 amd64 2.7.18-1~20.04.3 [248 kB]
# Get:6 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:7 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:8 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Fetched 4,298 kB in 1s (8,345 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libpython2.7-minimal:amd64.
# (Reading database ... 63243 files and directories currently installed.)
# Preparing to unpack .../0-libpython2.7-minimal_2.7.18-1~20.04.3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  3%] [#.........................................................] 8Unpacking libpython2.7-minimal:amd64 (2.7.18-1~20.04.3) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package python2.7-minimal.
# Preparing to unpack .../1-python2.7-minimal_2.7.18-1~20.04.3_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking python2.7-minimal (2.7.18-1~20.04.3) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package python2-minimal.
# Preparing to unpack .../2-python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libpython2.7-stdlib:amd64.
# Preparing to unpack .../3-libpython2.7-stdlib_2.7.18-1~20.04.3_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libpython2.7-stdlib:amd64 (2.7.18-1~20.04.3) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package python2.7.
# Preparing to unpack .../4-python2.7_2.7.18-1~20.04.3_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking python2.7 (2.7.18-1~20.04.3) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../5-libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# 7Progress: [ 36%] [#####################.....................................] 8Setting up libpython2.7-minimal:amd64 (2.7.18-1~20.04.3) ...
# 7Progress: [ 39%] [######################....................................] 87Progress: [ 42%] [########################..................................] 8Setting up python2.7-minimal (2.7.18-1~20.04.3) ...
# 7Progress: [ 45%] [##########################................................] 87Progress: [ 48%] [############################..............................] 8Setting up python2-minimal (2.7.17-2ubuntu4) ...
# 7Progress: [ 52%] [#############################.............................] 87Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package python2.
# (Reading database ... 63990 files and directories currently installed.)
# Preparing to unpack .../python2_2.7.17-2ubuntu4_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking python2 (2.7.17-2ubuntu4) ...
# 7Progress: [ 61%] [###################################.......................] 8Selecting previously unselected package python-opengl.
# Preparing to unpack .../python-opengl_3.1.0+dfsg-2build1_all.deb ...
# 7Progress: [ 64%] [####################################......................] 8Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libpython2.7-stdlib:amd64 (2.7.18-1~20.04.3) ...
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 73%] [##########################################................] 8Setting up python2.7 (2.7.18-1~20.04.3) ...
# 7Progress: [ 76%] [###########################################...............] 87Progress: [ 79%] [#############################################.............] 8Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 85%] [#################################################.........] 8Setting up python2 (2.7.17-2ubuntu4) ...
# 7Progress: [ 88%] [##################################################........] 87Progress: [ 91%] [####################################################......] 8Setting up python-opengl (3.1.0+dfsg-2build1) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 97%] [########################################################..] 8Processing triggers for mime-support (3.64ubuntu1) ...
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   i965-va-driver intel-media-va-driver libaacs0 libaom0 libass9 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcdio-cdda2
#   libcdio-paranoia2 libcdio18 libchromaprint1 libcodec2-0.9 libdc1394-22
#   libflite1 libgme0 libgsm1 libiec61883-0 libigdgmm11 libjack-jackd2-0
#   liblilv-0-0 libmp3lame0 libmpg123-0 libmysofa1 libnorm1 libnuma1
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpgm-5.2-0
#   libpostproc55 libraw1394-11 librubberband2 libsamplerate0 libsdl2-2.0-0
#   libserd-0-0 libshine3 libslang2 libsnappy1v5 libsndio7.0 libsodium23
#   libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4 libswresample3
#   libswscale5 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2
#   libva2 libvdpau1 libvidstab1.1 libvorbisfile3 libvpx6 libwavpack1
#   libx264-155 libx265-179 libxvidcore4 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj jackd2 libportaudio2
#   opus-tools libraw1394-doc serdi sndiod sordi speex opencl-icd
#   libvdpau-va-gl1 nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg i965-va-driver intel-media-va-driver libaacs0 libaom0 libass9
#   libavc1394-0 libavcodec58 libavdevice58 libavfilter7 libavformat58
#   libavresample4 libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0
#   libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1 libcodec2-0.9
#   libdc1394-22 libflite1 libgme0 libgsm1 libiec61883-0 libigdgmm11
#   libjack-jackd2-0 liblilv-0-0 libmp3lame0 libmpg123-0 libmysofa1 libnorm1
#   libnuma1 libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0
#   libpgm-5.2-0 libpostproc55 libraw1394-11 librubberband2 libsamplerate0
#   libsdl2-2.0-0 libserd-0-0 libshine3 libslang2 libsnappy1v5 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau1 libvidstab1.1 libvorbisfile3 libvpx6
#   libwavpack1 libx264-155 libx265-179 libxvidcore4 libzmq5 libzvbi-common
#   libzvbi0 mesa-va-drivers mesa-vdpau-drivers ocl-icd-libopencl1 va-driver-all
#   vdpau-driver-all
# 0 upgraded, 81 newly installed, 0 to remove and 78 not upgraded.
# Need to get 49.5 MB of archives.
# After this operation, 219 MB of additional disk space will be used.
# Get:1 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libslang2 amd64 2.3.2-4 [429 kB]
# Get:2 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libsodium23 amd64 1.0.18-1 [150 kB]
# Get:3 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libnuma1 amd64 2.0.12-1 [20.8 kB]
# Get:4 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libusb-1.0-0 amd64 2:1.0.23-2build1 [46.5 kB]
# Get:5 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libaom0 amd64 1.0.0.errata1-3build1 [1,160 kB]
# Get:6 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libva2 amd64 2.7.0-2 [53.5 kB]
# Get:7 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libva-drm2 amd64 2.7.0-2 [7,044 B]
# Get:8 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libva-x11-2 amd64 2.7.0-2 [11.9 kB]
# Get:9 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libvdpau1 amd64 1.3-1ubuntu2 [25.6 kB]
# Get:10 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:11 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavutil56 amd64 7:4.2.7-0ubuntu0.1 [241 kB]
# Get:12 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libcodec2-0.9 amd64 0.9.2-2 [7,886 kB]
# Get:13 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libgsm1 amd64 1.0.18-2 [24.4 kB]
# Get:14 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libmp3lame0 amd64 3.100-3 [133 kB]
# Get:15 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 libopenjp2-7 amd64 2.3.1-1ubuntu4.20.04.1 [141 kB]
# Get:16 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libopus0 amd64 1.3.1-0ubuntu1 [191 kB]
# Get:17 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:18 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libsnappy1v5 amd64 1.1.8-1build1 [16.7 kB]
# Get:19 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu1.20.04.1 [53.2 kB]
# Get:20 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libsoxr0 amd64 0.1.3-2build1 [78.0 kB]
# Get:21 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libswresample3 amd64 7:4.2.7-0ubuntu0.1 [57.1 kB]
# Get:22 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu2 [162 kB]
# Get:23 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libtwolame0 amd64 0.4.0-2 [47.6 kB]
# Get:24 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libvpx6 amd64 1.8.2-1build1 [820 kB]
# Get:25 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 libwavpack1 amd64 5.2.0-1ubuntu0.1 [77.3 kB]
# Get:26 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libx264-155 amd64 2:0.155.2917+git0a84d98-2 [521 kB]
# Get:27 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libx265-179 amd64 3.2.1-1build1 [1,060 kB]
# Get:28 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:29 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libzvbi-common all 0.2.35-17 [32.5 kB]
# Get:30 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libzvbi0 amd64 0.2.35-17 [237 kB]
# Get:31 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavcodec58 amd64 7:4.2.7-0ubuntu0.1 [4,878 kB]
# Get:32 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:33 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libavc1394-0 amd64 0.5.4-5 [16.2 kB]
# Get:34 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libass9 amd64 1:0.14.0-2 [88.0 kB]
# Get:35 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libbluray2 amd64 1:1.2.0-1 [138 kB]
# Get:36 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libchromaprint1 amd64 1.4.3-3build1 [37.6 kB]
# Get:37 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libgme0 amd64 0.6.2-1build1 [123 kB]
# Get:38 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libmpg123-0 amd64 1.25.13-1 [124 kB]
# Get:39 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libvorbisfile3 amd64 1.3.6-2ubuntu1 [16.1 kB]
# Get:40 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libopenmpt0 amd64 0.4.11-1build1 [599 kB]
# Get:41 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 libssh-gcrypt-4 amd64 0.9.3-2ubuntu2.2 [202 kB]
# Get:42 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavformat58 amd64 7:4.2.7-0ubuntu0.1 [985 kB]
# Get:43 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2build1 [10.2 kB]
# Get:44 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libflite1 amd64 2.1-release-3 [12.8 MB]
# Get:45 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libserd-0-0 amd64 0.30.2-1 [46.6 kB]
# Get:46 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libsord-0-0 amd64 0.16.4-1 [19.5 kB]
# Get:47 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libsratom-0-0 amd64 0.6.4-1 [16.9 kB]
# Get:48 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 liblilv-0-0 amd64 0.24.6-1ubuntu0.1 [40.6 kB]
# Get:49 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libmysofa1 amd64 1.0~dfsg0-1 [39.2 kB]
# Get:50 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libpostproc55 amd64 7:4.2.7-0ubuntu0.1 [55.0 kB]
# Get:51 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libsamplerate0 amd64 0.1.9-2 [939 kB]
# Get:52 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 librubberband2 amd64 1.8.2-1build1 [89.4 kB]
# Get:53 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libswscale5 amd64 7:4.2.7-0ubuntu0.1 [157 kB]
# Get:54 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libvidstab1.1 amd64 1.1.0-2 [35.0 kB]
# Get:55 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libnorm1 amd64 1.5.8+dfsg2-2build1 [290 kB]
# Get:56 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libpgm-5.2-0 amd64 5.2.122~dfsg-3ubuntu1 [158 kB]
# Get:57 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libzmq5 amd64 4.3.2-2ubuntu1 [242 kB]
# Get:58 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavfilter7 amd64 7:4.2.7-0ubuntu0.1 [1,085 kB]
# Get:59 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 libcaca0 amd64 0.99.beta19-2.1ubuntu1.20.04.2 [203 kB]
# Get:60 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libcdio18 amd64 2.0.0-2 [58.6 kB]
# Get:61 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1 [17.6 kB]
# Get:62 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1 [16.2 kB]
# Get:63 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libdc1394-22 amd64 2.2.5-2.1 [79.6 kB]
# Get:64 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libiec61883-0 amd64 1.2.0-3 [24.3 kB]
# Get:65 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2ubuntu2 [267 kB]
# Get:66 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libopenal-data all 1:1.19.1-1 [162 kB]
# Get:67 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libsndio7.0 amd64 1.5.0-3 [24.5 kB]
# Get:68 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libopenal1 amd64 1:1.19.1-1 [492 kB]
# Get:69 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-2.0-0 amd64 2.0.10+dfsg1-3 [407 kB]
# Get:70 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavdevice58 amd64 7:4.2.7-0ubuntu0.1 [74.3 kB]
# Get:71 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 libavresample4 amd64 7:4.2.7-0ubuntu0.1 [54.2 kB]
# Get:72 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 ffmpeg amd64 7:4.2.7-0ubuntu0.1 [1,453 kB]
# Get:73 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libigdgmm11 amd64 20.1.1+ds1-1 [111 kB]
# Get:74 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 intel-media-va-driver amd64 20.1.1+dfsg1-1 [1,764 kB]
# Get:75 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libaacs0 amd64 0.9.0-2 [50.1 kB]
# Get:76 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 libbdplus0 amd64 0.1.2-3 [47.3 kB]
# Get:77 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 mesa-va-drivers amd64 21.2.6-0ubuntu0.1~20.04.2 [2,970 kB]
# Get:78 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 mesa-vdpau-drivers amd64 21.2.6-0ubuntu0.1~20.04.2 [3,089 kB]
# Get:79 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 i965-va-driver amd64 2.4.0-0ubuntu1 [924 kB]
# Get:80 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 va-driver-all amd64 2.7.0-2 [4,020 B]
# Get:81 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 vdpau-driver-all amd64 1.3-1ubuntu2 [4,596 B]
# Fetched 49.5 MB in 1s (35.4 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libslang2:amd64.
# (Reading database ... 66373 files and directories currently installed.)
# Preparing to unpack .../00-libslang2_2.3.2-4_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libslang2:amd64 (2.3.2-4) ...
# Selecting previously unselected package libsodium23:amd64.
# Preparing to unpack .../01-libsodium23_1.0.18-1_amd64.deb ...
# Unpacking libsodium23:amd64 (1.0.18-1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libnuma1:amd64.
# Preparing to unpack .../02-libnuma1_2.0.12-1_amd64.deb ...
# Unpacking libnuma1:amd64 (2.0.12-1) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../03-libusb-1.0-0_2%3a1.0.23-2build1_amd64.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libusb-1.0-0:amd64 (2:1.0.23-2build1) ...
# Selecting previously unselected package libaom0:amd64.
# Preparing to unpack .../04-libaom0_1.0.0.errata1-3build1_amd64.deb ...
# Unpacking libaom0:amd64 (1.0.0.errata1-3build1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../05-libva2_2.7.0-2_amd64.deb ...
# Unpacking libva2:amd64 (2.7.0-2) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../06-libva-drm2_2.7.0-2_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libva-drm2:amd64 (2.7.0-2) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../07-libva-x11-2_2.7.0-2_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.7.0-2) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../08-libvdpau1_1.3-1ubuntu2_amd64.deb ...
# 7Progress: [  5%] [###.......................................................] 8Unpacking libvdpau1:amd64 (1.3-1ubuntu2) ...
# Selecting previously unselected package ocl-icd-libopencl1:amd64.
# Preparing to unpack .../09-ocl-icd-libopencl1_2.2.11-1ubuntu1_amd64.deb ...
# Unpacking ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../10-libavutil56_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libcodec2-0.9:amd64.
# Preparing to unpack .../11-libcodec2-0.9_0.9.2-2_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libcodec2-0.9:amd64 (0.9.2-2) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../12-libgsm1_1.0.18-2_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.18-2) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../13-libmp3lame0_3.100-3_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-3) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../14-libopenjp2-7_2.3.1-1ubuntu4.20.04.1_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.3.1-1ubuntu4.20.04.1) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../15-libopus0_1.3.1-0ubuntu1_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0ubuntu1) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../16-libshine3_3.1.1-2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../17-libsnappy1v5_1.1.8-1build1_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.8-1build1) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../18-libspeex1_1.2~rc1.2-1.1ubuntu1.20.04.1_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1.1ubuntu1.20.04.1) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../19-libsoxr0_0.1.3-2build1_amd64.deb ...
# 7Progress: [ 12%] [######....................................................] 8Unpacking libsoxr0:amd64 (0.1.3-2build1) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../20-libswresample3_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libswresample3:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../21-libtheora0_1.1.1+dfsg.1-15ubuntu2_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu2) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../22-libtwolame0_0.4.0-2_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.4.0-2) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libvpx6:amd64.
# Preparing to unpack .../23-libvpx6_1.8.2-1build1_amd64.deb ...
# Unpacking libvpx6:amd64 (1.8.2-1build1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../24-libwavpack1_5.2.0-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libwavpack1:amd64 (5.2.0-1ubuntu0.1) ...
# Selecting previously unselected package libx264-155:amd64.
# Preparing to unpack .../25-libx264-155_2%3a0.155.2917+git0a84d98-2_amd64.deb ...
# Unpacking libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libx265-179:amd64.
# Preparing to unpack .../26-libx265-179_3.2.1-1build1_amd64.deb ...
# Unpacking libx265-179:amd64 (3.2.1-1build1) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../27-libxvidcore4_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.7-1) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../28-libzvbi-common_0.2.35-17_all.deb ...
# Unpacking libzvbi-common (0.2.35-17) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../29-libzvbi0_0.2.35-17_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libzvbi0:amd64 (0.2.35-17) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../30-libavcodec58_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavcodec58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../31-libraw1394-11_2.1.2-1_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-1) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../32-libavc1394-0_0.5.4-5_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libavc1394-0:amd64 (0.5.4-5) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../33-libass9_1%3a0.14.0-2_amd64.deb ...
# Unpacking libass9:amd64 (1:0.14.0-2) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../34-libbluray2_1%3a1.2.0-1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libbluray2:amd64 (1:1.2.0-1) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../35-libchromaprint1_1.4.3-3build1_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.4.3-3build1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../36-libgme0_0.6.2-1build1_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.2-1build1) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../37-libmpg123-0_1.25.13-1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libmpg123-0:amd64 (1.25.13-1) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../38-libvorbisfile3_1.3.6-2ubuntu1_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.6-2ubuntu1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../39-libopenmpt0_0.4.11-1build1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.4.11-1build1) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../40-libssh-gcrypt-4_0.9.3-2ubuntu2.2_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.9.3-2ubuntu2.2) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../41-libavformat58_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavformat58:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../42-libbs2b0_3.1.0+dfsg-2.2build1_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../43-libflite1_2.1-release-3_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-3) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../44-libserd-0-0_0.30.2-1_amd64.deb ...
# Unpacking libserd-0-0:amd64 (0.30.2-1) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../45-libsord-0-0_0.16.4-1_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libsord-0-0:amd64 (0.16.4-1) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../46-libsratom-0-0_0.6.4-1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.4-1) ...
# Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../47-liblilv-0-0_0.24.6-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking liblilv-0-0:amd64 (0.24.6-1ubuntu0.1) ...
# Selecting previously unselected package libmysofa1:amd64.
# Preparing to unpack .../48-libmysofa1_1.0~dfsg0-1_amd64.deb ...
# Unpacking libmysofa1:amd64 (1.0~dfsg0-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libpostproc55:amd64.
# Preparing to unpack .../49-libpostproc55_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libpostproc55:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../50-libsamplerate0_0.1.9-2_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libsamplerate0:amd64 (0.1.9-2) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../51-librubberband2_1.8.2-1build1_amd64.deb ...
# Unpacking librubberband2:amd64 (1.8.2-1build1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libswscale5:amd64.
# Preparing to unpack .../52-libswscale5_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libswscale5:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../53-libvidstab1.1_1.1.0-2_amd64.deb ...
# Unpacking libvidstab1.1:amd64 (1.1.0-2) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../54-libnorm1_1.5.8+dfsg2-2build1_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.8+dfsg2-2build1) ...
# Selecting previously unselected package libpgm-5.2-0:amd64.
# Preparing to unpack .../55-libpgm-5.2-0_5.2.122~dfsg-3ubuntu1_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libpgm-5.2-0:amd64 (5.2.122~dfsg-3ubuntu1) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../56-libzmq5_4.3.2-2ubuntu1_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.2-2ubuntu1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libavfilter7:amd64.
# Preparing to unpack .../57-libavfilter7_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavfilter7:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../58-libcaca0_0.99.beta19-2.1ubuntu1.20.04.2_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libcaca0:amd64 (0.99.beta19-2.1ubuntu1.20.04.2) ...
# Selecting previously unselected package libcdio18:amd64.
# Preparing to unpack .../59-libcdio18_2.0.0-2_amd64.deb ...
# Unpacking libcdio18:amd64 (2.0.0-2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../60-libcdio-cdda2_10.2+2.0.0-1_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libcdio-cdda2:amd64 (10.2+2.0.0-1) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../61-libcdio-paranoia2_10.2+2.0.0-1_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+2.0.0-1) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libdc1394-22:amd64.
# Preparing to unpack .../62-libdc1394-22_2.2.5-2.1_amd64.deb ...
# Unpacking libdc1394-22:amd64 (2.2.5-2.1) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../63-libiec61883-0_1.2.0-3_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libiec61883-0:amd64 (1.2.0-3) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../64-libjack-jackd2-0_1.9.12~dfsg-2ubuntu2_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2ubuntu2) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libopenal-data.
# Preparing to unpack .../65-libopenal-data_1%3a1.19.1-1_all.deb ...
# Unpacking libopenal-data (1:1.19.1-1) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../66-libsndio7.0_1.5.0-3_amd64.deb ...
# Unpacking libsndio7.0:amd64 (1.5.0-3) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../67-libopenal1_1%3a1.19.1-1_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.19.1-1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../68-libsdl2-2.0-0_2.0.10+dfsg1-3_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libsdl2-2.0-0:amd64 (2.0.10+dfsg1-3) ...
# Selecting previously unselected package libavdevice58:amd64.
# Preparing to unpack .../69-libavdevice58_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavdevice58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 43%] [########################..................................] 8Selecting previously unselected package libavresample4:amd64.
# Preparing to unpack .../70-libavresample4_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# Unpacking libavresample4:amd64 (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../71-ffmpeg_7%3a4.2.7-0ubuntu0.1_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking ffmpeg (7:4.2.7-0ubuntu0.1) ...
# Selecting previously unselected package libigdgmm11:amd64.
# Preparing to unpack .../72-libigdgmm11_20.1.1+ds1-1_amd64.deb ...
# Unpacking libigdgmm11:amd64 (20.1.1+ds1-1) ...
# Selecting previously unselected package intel-media-va-driver:amd64.
# Preparing to unpack .../73-intel-media-va-driver_20.1.1+dfsg1-1_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking intel-media-va-driver:amd64 (20.1.1+dfsg1-1) ...
# Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../74-libaacs0_0.9.0-2_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-2) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../75-libbdplus0_0.1.2-3_amd64.deb ...
# Unpacking libbdplus0:amd64 (0.1.2-3) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../76-mesa-va-drivers_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking mesa-va-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../77-mesa-vdpau-drivers_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking mesa-vdpau-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../78-i965-va-driver_2.4.0-0ubuntu1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.4.0-0ubuntu1) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../79-va-driver-all_2.7.0-2_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.7.0-2) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../80-vdpau-driver-all_1.3-1ubuntu2_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.3-1ubuntu2) ...
# Setting up libgme0:amd64 (0.6.2-1build1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libssh-gcrypt-4:amd64 (0.9.3-2ubuntu2.2) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libraw1394-11:amd64 (2.1.2-1) ...
# Setting up libsodium23:amd64 (1.0.18-1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libmpg123-0:amd64 (1.25.13-1) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1.1ubuntu1.20.04.1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libshine3:amd64 (3.1.1-2) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libtwolame0:amd64 (0.4.0-2) ...
# Setting up libgsm1:amd64 (1.0.18-2) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libsoxr0:amd64 (0.1.3-2build1) ...
# Setting up libaom0:amd64 (1.0.0.errata1-3build1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libnorm1:amd64 (1.5.8+dfsg2-2build1) ...
# Setting up libmysofa1:amd64 (1.0~dfsg0-1) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libcdio18:amd64 (2.0.0-2) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libxvidcore4:amd64 (2:1.3.7-1) ...
# Setting up libsnappy1v5:amd64 (1.1.8-1build1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libvorbisfile3:amd64 (1.3.6-2ubuntu1) ...
# Setting up libass9:amd64 (1:0.14.0-2) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libslang2:amd64 (2.3.2-4) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libva2:amd64 (2.7.0-2) ...
# Setting up libigdgmm11:amd64 (20.1.1+ds1-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libcodec2-0.9:amd64 (0.9.2-2) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libopus0:amd64 (1.3.1-0ubuntu1) ...
# Setting up intel-media-va-driver:amd64 (20.1.1+dfsg1-1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libaacs0:amd64 (0.9.0-2) ...
# Setting up libsndio7.0:amd64 (1.5.0-3) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libbdplus0:amd64 (0.1.2-3) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libnuma1:amd64 (2.0.12-1) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libflite1:amd64 (2.1-release-3) ...
# Setting up libva-drm2:amd64 (2.7.0-2) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libvpx6:amd64 (1.8.2-1build1) ...
# Setting up libvdpau1:amd64 (1.3-1ubuntu2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libwavpack1:amd64 (5.2.0-1ubuntu0.1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libopenjp2-7:amd64 (2.3.1-1ubuntu4.20.04.1) ...
# Setting up libopenal-data (1:1.19.1-1) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up libusb-1.0-0:amd64 (2:1.0.23-2build1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up mesa-va-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libbluray2:amd64 (1:1.2.0-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libsdl2-2.0-0:amd64 (2.0.10+dfsg1-3) ...
# Setting up libsamplerate0:amd64 (0.1.9-2) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libva-x11-2:amd64 (2.7.0-2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libopenmpt0:amd64 (0.4.11-1build1) ...
# Setting up libzvbi-common (0.2.35-17) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libmp3lame0:amd64 (3.100-3) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up i965-va-driver:amd64 (2.4.0-0ubuntu1) ...
# Setting up libpgm-5.2-0:amd64 (5.2.122~dfsg-3ubuntu1) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libiec61883-0:amd64 (1.2.0-3) ...
# Setting up libserd-0-0:amd64 (0.30.2-1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libavc1394-0:amd64 (0.5.4-5) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up mesa-vdpau-drivers:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libzvbi0:amd64 (0.2.35-17) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libzmq5:amd64 (4.3.2-2ubuntu1) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.1ubuntu1.20.04.2) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libx265-179:amd64 (3.2.1-1build1) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1) ...
# Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libdc1394-22:amd64 (2.2.5-2.1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libopenal1:amd64 (1:1.19.1-1) ...
# Setting up libavutil56:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up va-driver-all:amd64 (2.7.0-2) ...
# Setting up libpostproc55:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up librubberband2:amd64 (1.8.2-1build1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2ubuntu2) ...
# Setting up vdpau-driver-all:amd64 (1.3-1ubuntu2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libsord-0-0:amd64 (0.16.4-1) ...
# Setting up libsratom-0-0:amd64 (0.6.4-1) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libswscale5:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up liblilv-0-0:amd64 (0.24.6-1ubuntu0.1) ...
# Setting up libswresample3:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libavresample4:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libavcodec58:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up libchromaprint1:amd64 (1.4.3-3build1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libavformat58:amd64 (7:4.2.7-0ubuntu0.1) ...
# Setting up libavfilter7:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libavdevice58:amd64 (7:4.2.7-0ubuntu0.1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up ffmpeg (7:4.2.7-0ubuntu0.1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libunwind8 libxfont2 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libunwind8 libxfont2 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 8 newly installed, 0 to remove and 78 not upgraded.
# Need to get 7,665 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libunwind8 amd64 1.2.1-9build1 [47.6 kB]
# Get:2 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:3 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:4 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:5 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:6 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:7 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.5 [27.1 kB]
# Get:8 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.5 [780 kB]
# Fetched 7,665 kB in 0s (51.8 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libunwind8:amd64.
# (Reading database ... 66947 files and directories currently installed.)
# Preparing to unpack .../0-libunwind8_1.2.1-9build1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  3%] [#.........................................................] 8Unpacking libunwind8:amd64 (1.2.1-9build1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.3-1_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../2-x11-xkb-utils_7.7+5_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking x11-xkb-utils (7.7+5) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../3-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../4-xfonts-utils_1%3a7.7+6_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking xfonts-utils (1:7.7+6) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package xfonts-base.
# Preparing to unpack .../5-xfonts-base_1%3a1.0.5_all.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking xfonts-base (1:1.0.5) ...
# 7Progress: [ 36%] [#####################.....................................] 8Selecting previously unselected package xserver-common.
# Preparing to unpack .../6-xserver-common_2%3a1.20.13-1ubuntu1~20.04.5_all.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.5) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package xvfb.
# Preparing to unpack .../7-xvfb_2%3a1.20.13-1ubuntu1~20.04.5_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.5) ...
# 7Progress: [ 48%] [############################..............................] 8Setting up x11-xkb-utils (7.7+5) ...
# 7Progress: [ 52%] [#############################.............................] 87Progress: [ 55%] [###############################...........................] 8Setting up libunwind8:amd64 (1.2.1-9build1) ...
# 7Progress: [ 58%] [#################################.........................] 87Progress: [ 61%] [###################################.......................] 8Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# 7Progress: [ 64%] [####################################......................] 87Progress: [ 67%] [######################################....................] 8Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.5) ...
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 73%] [##########################################................] 8Setting up libxfont2:amd64 (1:2.0.3-1) ...
# 7Progress: [ 76%] [###########################################...............] 87Progress: [ 79%] [#############################################.............] 8Setting up xvfb (2:1.20.13-1ubuntu1~20.04.5) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 85%] [#################################################.........] 8Setting up xfonts-utils (1:7.7+6) ...
# 7Progress: [ 88%] [##################################################........] 87Progress: [ 91%] [####################################################......] 8Setting up xfonts-base (1:1.0.5) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 97%] [########################################################..] 8Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
#
# 78Requirement already satisfied: pyvirtualdisplay in /datasci/lib/python3.8/site-packages (3.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Additional dependencies for RL Baselines3 Zoo
# !apt update -yqq
# !apt install -y swig cmake freeglut3-dev
# Out:
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# freeglut3-dev is already the newest version (2.8.1-3).
# swig is already the newest version (4.0.1-5build1).
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 78 not upgraded.

# %%
# !pip install pyglet==1.5.1
# Out:
# Collecting pyglet==1.5.1
#   Downloading pyglet-1.5.1-py2.py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyglet
# Successfully installed pyglet-1.5.1
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !pip uninstall -y -q torch torchvision torchaudio
# !pip install -q torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# WARNING: Skipping torchaudio as it is not installed.

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 78 not upgraded.
# Need to get 3,316 kB of archives.
# After this operation, 11.1 MB of additional disk space will be used.
# Get:1 http://us-west-2.ec2.archive.ubuntu.com/ubuntu focal/universe amd64 git-lfs amd64 2.9.2-1 [3,316 kB]
# Fetched 3,316 kB in 0s (17.4 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package git-lfs.
# (Reading database ... 67511 files and directories currently installed.)
# Preparing to unpack .../git-lfs_2.9.2-1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [ 20%] [###########...............................................] 8Unpacking git-lfs (2.9.2-1) ...
# 7Progress: [ 40%] [#######################...................................] 8Setting up git-lfs (2.9.2-1) ...
# 7Progress: [ 60%] [##################################........................] 87Progress: [ 80%] [##############################################............] 8
# 78

# %% [markdown]
# ## Clone RL-Baselines3 Zoo Repo 📚
# You can now directly install from python package `pip install rl_zoo3` but since we want **the full installation with extra environments and dependencies** we're going to clone `RL-Baselines3-Zoo` repository and install from source.

# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Cloning into 'rl-baselines3-zoo'...
# remote: Enumerating objects: 4732, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 4732 (delta 2), reused 5 (delta 1), pack-reused 4721732)Receiving objects:  26% (1231/4732)Receiving objects:  67% (3171/4732)
# Receiving objects: 100% (4732/4732), 2.97 MiB | 18.55 MiB/s, done.
# Resolving deltas: 100% (3134/3134), done.solving deltas:  60% (1898/3134)

# %% [markdown]
# ## Install dependencies 🔽
# We can now install the dependencies RL-Baselines3 Zoo needs (this can take 5min ⏲)

# %%
cd rl-baselines3-zoo
# Out:
# /OpenMail/hf_rl_class/unit3/rl-baselines3-zoo

# %%
# !pip install -r requirements.txt
# Out:
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting stable-baselines3[docs,extra,tests]>=1.7.0a10
#   Downloading stable_baselines3-1.7.0a10-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 28.6 MB/s eta 0:00:00
# Collecting sb3-contrib>=1.7.0a10
#   Downloading sb3_contrib-1.7.0a10-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.9/78.9 kB 15.2 MB/s eta 0:00:00
# Collecting box2d-py==2.3.8
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 58.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 MB 37.9 MB/s eta 0:00:0000:0100:01
# Collecting gym-minigrid
#   Downloading gym_minigrid-1.2.2-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 16.3 MB/s eta 0:00:00
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: optuna in /datasci/lib/python3.8/site-packages (from -r rl-baselines3-zoo/requirements.txt (line 8)) (2.10.1)
# Collecting pytablewriter~=0.64
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /datasci/lib/python3.8/site-packages (from -r rl-baselines3-zoo/requirements.txt (line 10)) (5.4.1)
# Requirement already satisfied: cloudpickle>=1.5.0 in /datasci/lib/python3.8/site-packages (from -r rl-baselines3-zoo/requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: plotly in /datasci/lib/python3.8/site-packages (from -r rl-baselines3-zoo/requirements.txt (line 12)) (5.9.0)
# Collecting panda-gym==1.1.1
#   Downloading panda_gym-1.1.1-py3-none-any.whl (21 kB)
# Collecting rliable>=1.0.5
#   Downloading rliable-1.0.8-py3-none-any.whl (19 kB)
# Collecting wandb
#   Downloading wandb-0.13.7-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 108.3 MB/s eta 0:00:00
# Collecting huggingface_sb3<3.*,>=2.2.1
#   Downloading huggingface_sb3-2.2.4-py3-none-any.whl (9.4 kB)
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /datasci/lib/python3.8/site-packages (from -r rl-baselines3-zoo/requirements.txt (line 18)) (4.64.0)
# Collecting rich
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 40.9 MB/s eta 0:00:00
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.18.0 in /datasci/lib/python3.8/site-packages (from gym==0.21->-r rl-baselines3-zoo/requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pandas in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: matplotlib in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (3.5.2)
# Requirement already satisfied: torch>=1.11 in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.11.0)
# Collecting sphinx
#   Downloading sphinx-5.3.0-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 116.3 MB/s eta 0:00:00
# Collecting sphinx-autobuild
#   Downloading sphinx_autobuild-2021.3.14-py3-none-any.whl (9.9 kB)
# Collecting sphinx-copybutton
#   Downloading sphinx_copybutton-0.5.1-py3-none-any.whl (13 kB)
# Collecting sphinxcontrib.spelling
#   Downloading sphinxcontrib_spelling-7.7.0-py3-none-any.whl (15 kB)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.1.1-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 113.8 MB/s eta 0:00:00
# Collecting sphinx-autodoc-typehints
#   Downloading sphinx_autodoc_typehints-1.19.5-py3-none-any.whl (12 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.9.1)
# Requirement already satisfied: psutil in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (5.9.1)
# Requirement already satisfied: pillow in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (9.0.1)
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 49.8 MB/s eta 0:00:0000:0100:01
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 115.4 MB/s eta 0:00:00
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Collecting flake8-bugbear
#   Downloading flake8_bugbear-22.12.6-py3-none-any.whl (23 kB)
# Requirement already satisfied: isort>=5.0 in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (5.10.1)
# Requirement already satisfied: scipy>=1.4.1 in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.7.3)
# Requirement already satisfied: flake8>=3.8 in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (4.0.1)
# Collecting pytest-env
#   Downloading pytest_env-0.8.1-py3-none-any.whl (5.2 kB)
# Collecting black
#   Downloading black-22.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 110.5 MB/s eta 0:00:00
# Collecting pytest-xdist
#   Downloading pytest_xdist-3.1.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: pytest in /datasci/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (7.1.2)
# Collecting pytest-cov
#   Downloading pytest_cov-4.0.0-py3-none-any.whl (21 kB)
# Collecting pytype
#   Downloading pytype-2022.12.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 121.9 MB/s eta 0:00:00
# Collecting mypy
#   Downloading mypy-0.991-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 94.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: importlib-resources in /datasci/lib/python3.8/site-packages (from ale-py==0.7.4->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (5.8.0)
# Collecting gym-minigrid
#   Downloading gym_minigrid-1.2.1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 14.3 MB/s eta 0:00:00
#   Downloading gym_minigrid-1.2.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 14.7 MB/s eta 0:00:00
#   Downloading gym_minigrid-1.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 11.7 MB/s eta 0:00:00
#   Downloading gym_minigrid-1.0.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in /datasci/lib/python3.8/site-packages (from scikit-optimize->-r rl-baselines3-zoo/requirements.txt (line 7)) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /datasci/lib/python3.8/site-packages (from scikit-optimize->-r rl-baselines3-zoo/requirements.txt (line 7)) (1.1.0)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cmaes>=0.8.2 in /datasci/lib/python3.8/site-packages (from optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (0.8.2)
# Requirement already satisfied: colorlog in /datasci/lib/python3.8/site-packages (from optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (6.6.0)
# Requirement already satisfied: cliff in /datasci/lib/python3.8/site-packages (from optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (3.10.1)
# Requirement already satisfied: alembic in /datasci/lib/python3.8/site-packages (from optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /datasci/lib/python3.8/site-packages (from optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (1.4.39)
# Requirement already satisfied: packaging>=20.0 in /datasci/lib/python3.8/site-packages (from optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (21.3)
# Requirement already satisfied: setuptools>=38.3.0 in /datasci/lib/python3.8/site-packages (from pytablewriter~=0.64->-r rl-baselines3-zoo/requirements.txt (line 9)) (44.0.0)
# Collecting tabledata<2,>=1.3.0
#   Downloading tabledata-1.3.0-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5
#   Downloading tcolorpy-0.1.2-py3-none-any.whl (7.9 kB)
# Collecting pathvalidate<3,>=2.3.0
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting DataProperty<2,>=0.55.0
#   Downloading DataProperty-0.55.0-py3-none-any.whl (26 kB)
# Collecting typepy[datetime]<2,>=1.2.0
#   Downloading typepy-1.3.0-py3-none-any.whl (31 kB)
# Collecting mbstrdecoder<2,>=1.0.0
#   Downloading mbstrdecoder-1.1.1-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /datasci/lib/python3.8/site-packages (from plotly->-r rl-baselines3-zoo/requirements.txt (line 12)) (8.0.1)
# Requirement already satisfied: absl-py>=0.9.0 in /datasci/lib/python3.8/site-packages (from rliable>=1.0.5->-r rl-baselines3-zoo/requirements.txt (line 14)) (1.1.0)
# Collecting arch==5.3.0
#   Downloading arch-5.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (907 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 907.3/907.3 kB 92.2 MB/s eta 0:00:00
# Collecting property-cached>=1.6.4
#   Downloading property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Collecting statsmodels>=0.11
#   Downloading statsmodels-0.13.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 123.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /datasci/lib/python3.8/site-packages (from wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (3.18.1)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /datasci/lib/python3.8/site-packages (from wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (2.28.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /datasci/lib/python3.8/site-packages (from wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /datasci/lib/python3.8/site-packages (from wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (8.0.4)
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: GitPython>=1.0.0 in /datasci/lib/python3.8/site-packages (from wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (3.1.27)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 78.7 MB/s eta 0:00:00
# Requirement already satisfied: wasabi in /datasci/lib/python3.8/site-packages (from huggingface_sb3<3.*,>=2.2.1->-r rl-baselines3-zoo/requirements.txt (line 16)) (0.9.1)
# Requirement already satisfied: huggingface-hub~=0.8 in /datasci/lib/python3.8/site-packages (from huggingface_sb3<3.*,>=2.2.1->-r rl-baselines3-zoo/requirements.txt (line 16)) (0.8.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /datasci/lib/python3.8/site-packages (from rich->-r rl-baselines3-zoo/requirements.txt (line 19)) (2.12.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /datasci/lib/python3.8/site-packages (from rich->-r rl-baselines3-zoo/requirements.txt (line 19)) (4.3.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /datasci/lib/python3.8/site-packages (from importlib-metadata~=4.13->-r rl-baselines3-zoo/requirements.txt (line 20)) (3.8.0)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.5.0.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six>=1.4.0 in /datasci/lib/python3.8/site-packages (from docker-pycreds>=0.4.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /datasci/lib/python3.8/site-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /datasci/lib/python3.8/site-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /datasci/lib/python3.8/site-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /datasci/lib/python3.8/site-packages (from GitPython>=1.0.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (4.0.9)
# Requirement already satisfied: filelock in /datasci/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3<3.*,>=2.2.1->-r rl-baselines3-zoo/requirements.txt (line 16)) (3.7.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /datasci/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /datasci/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /datasci/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in /datasci/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /datasci/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (4.33.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /datasci/lib/python3.8/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->-r rl-baselines3-zoo/requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: pytz>=2020.1 in /datasci/lib/python3.8/site-packages (from pandas->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in /datasci/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /datasci/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /datasci/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /datasci/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /datasci/lib/python3.8/site-packages (from scikit-learn>=0.20.0->scikit-optimize->-r rl-baselines3-zoo/requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /datasci/lib/python3.8/site-packages (from sqlalchemy>=1.1.0->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: markdown>=2.6.8 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.43.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.35.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /datasci/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: Mako in /datasci/lib/python3.8/site-packages (from alembic->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (1.2.0)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.10.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /datasci/lib/python3.8/site-packages (from black->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.5.2)
# Requirement already satisfied: tomli>=1.1.0 in /datasci/lib/python3.8/site-packages (from black->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.0.1)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: autopage>=0.4.0 in /datasci/lib/python3.8/site-packages (from cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /datasci/lib/python3.8/site-packages (from cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /datasci/lib/python3.8/site-packages (from cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (5.9.0)
# Requirement already satisfied: stevedore>=2.0.1 in /datasci/lib/python3.8/site-packages (from cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: cmd2>=1.0.0 in /datasci/lib/python3.8/site-packages (from cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: attrs>=19.2.0 in /datasci/lib/python3.8/site-packages (from flake8-bugbear->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (21.4.0)
# Requirement already satisfied: py>=1.8.2 in /datasci/lib/python3.8/site-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.11.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /datasci/lib/python3.8/site-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: iniconfig in /datasci/lib/python3.8/site-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.1.1)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-7.0.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.1/217.1 kB 37.5 MB/s eta 0:00:00
# Collecting pytest
#   Downloading pytest-7.2.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 35.6 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting execnet>=1.1
#   Downloading execnet-1.9.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: toml>=0.10.2 in /datasci/lib/python3.8/site-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.10.2)
# Collecting ninja>=1.10.0.post2
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 31.1 MB/s eta 0:00:00
# Collecting libcst>=0.4.5
#   Downloading libcst-0.4.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 116.5 MB/s eta 0:00:00
# Collecting networkx<2.8.4
#   Downloading networkx-2.8.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 103.4 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.8.10 in /datasci/lib/python3.8/site-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.8.10)
# Requirement already satisfied: jinja2>=3.1.2 in /datasci/lib/python3.8/site-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (3.1.2)
# Collecting pydot>=1.4.2
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting importlab>=0.8
#   Downloading importlab-0.8-py2.py3-none-any.whl (21 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 21.8 MB/s eta 0:00:00
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 20.6 MB/s eta 0:00:00
# Collecting docutils<0.20,>=0.14
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 75.1 MB/s eta 0:00:00
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 18.7 MB/s eta 0:00:00
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 14.6 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 21.1 MB/s eta 0:00:00
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: babel>=2.9 in /datasci/lib/python3.8/site-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.10.3)
# Collecting livereload
#   Downloading livereload-2.6.3-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: colorama in /datasci/lib/python3.8/site-packages (from sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.4.5)
# Collecting docutils<0.20,>=0.14
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.5/575.5 kB 72.0 MB/s eta 0:00:00
# Collecting PyEnchant>=3.1.1
#   Downloading pyenchant-3.2.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: pyperclip>=1.6 in /datasci/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /datasci/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna->-r rl-baselines3-zoo/requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /datasci/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->-r rl-baselines3-zoo/requirements.txt (line 15)) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /datasci/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /datasci/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /datasci/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /datasci/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /datasci/lib/python3.8/site-packages (from jinja2>=3.1.2->pytype->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (2.1.1)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 42.8 MB/s eta 0:00:00
# Collecting libtorrent
#   Using cached libtorrent-2.0.7-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.6 MB)
# Requirement already satisfied: tornado in /datasci/lib/python3.8/site-packages (from livereload->sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /datasci/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /datasci/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[docs,extra,tests]>=1.7.0a10->-r rl-baselines3-zoo/requirements.txt (line 2)) (3.2.0)
# Building wheels for collected packages: gym, box2d-py, promise, pathtools, AutoROM.accept-rom-license
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616826 sha256=2224a7e1e31a15e99f7ed3ee2f33cf6b9d32b4ff925b5982d6e3c50e3cda3b72
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp38-cp38-linux_x86_64.whl size=2806016 sha256=a2c051f6c42e1ce9e67ea49f24374e38b56b685dfa1499c3075fb39675dc6ff0
#   Stored in directory: /root/.cache/pip/wheels/cc/4f/d6/44eb0a9e6fea384e58f19cb0c4125e46a23af2b33fe3a7e81c
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21492 sha256=2b91dad49ad56fca6becda4c7b51ef91c3eb3bbe172c0fd545e7e63f6920ad1f
#   Stored in directory: /root/.cache/pip/wheels/54/aa/01/724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8785 sha256=8fc31915e993c29a7ccdd4c512a7dcc7c1b91314290148fdb1124b7ad635e96c
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.5.0-py3-none-any.whl size=447759 sha256=97adbe82b4fa85c22a4f7e36fea48746e82fb3967e54e2043558cb8486744a67
#   Stored in directory: /root/.cache/pip/wheels/bf/c9/25/578470ae932b494c313dc22e6c57afff192140fb3cd5acf185
# Successfully built gym box2d-py promise pathtools AutoROM.accept-rom-license
# Installing collected packages: snowballstemmer, pybullet, pathtools, ninja, mypy-extensions, libtorrent, commonmark, box2d-py, alabaster, typing-inspect, tcolorpy, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, shortuuid, setproctitle, rich, pyyaml, PyEnchant, pydot, property-cached, promise, patsy, pathvalidate, pathspec, opencv-python, networkx, mypy, mbstrdecoder, livereload, importlib-metadata, imagesize, gym, execnet, exceptiongroup, docutils, docker-pycreds, coverage, typepy, sphinx, pytest, pyaml, panda-gym, libcst, importlab, gym-minigrid, flake8-bugbear, black, AutoROM.accept-rom-license, autorom, ale-py, wandb, statsmodels, stable-baselines3, sphinxcontrib.spelling, sphinx-rtd-theme, sphinx-copybutton, sphinx-autodoc-typehints, sphinx-autobuild, seaborn, scikit-optimize, pytype, pytest-xdist, pytest-env, pytest-cov, huggingface_sb3, sb3-contrib, DataProperty, arch, tabledata, rliable, pytablewriter
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.8.4
#     Uninstalling networkx-2.8.4:
#       Successfully uninstalled networkx-2.8.4
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.12.0
#     Uninstalling importlib-metadata-4.12.0:
#       Successfully uninstalled importlib-metadata-4.12.0
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.1.2
#     Uninstalling pytest-7.1.2:
#       Successfully uninstalled pytest-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googleads 32.0.0 requires PyYAML<6.0,>=5.1, but you have pyyaml 6.0 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.5.0 DataProperty-0.55.0 PyEnchant-3.2.2 alabaster-0.7.12 ale-py-0.7.4 arch-5.3.0 autorom-0.4.2 black-22.12.0 box2d-py-2.3.8 commonmark-0.9.1 coverage-7.0.1 docker-pycreds-0.4.0 docutils-0.17.1 exceptiongroup-1.1.0 execnet-1.9.0 flake8-bugbear-22.12.6 gym-0.21.0 gym-minigrid-1.0.3 huggingface_sb3-2.2.4 imagesize-1.4.1 importlab-0.8 importlib-metadata-4.13.0 libcst-0.4.9 libtorrent-2.0.7 livereload-2.6.3 mbstrdecoder-1.1.1 mypy-0.991 mypy-extensions-0.4.3 networkx-2.8.3 ninja-1.11.1 opencv-python-4.6.0.66 panda-gym-1.1.1 pathspec-0.10.3 pathtools-0.1.2 pathvalidate-2.5.2 patsy-0.5.3 promise-2.3 property-cached-1.6.4 pyaml-21.10.1 pybullet-3.2.5 pydot-1.4.2 pytablewriter-0.64.2 pytest-7.2.0 pytest-cov-4.0.0 pytest-env-0.8.1 pytest-xdist-3.1.0 pytype-2022.12.15 pyyaml-6.0 rich-12.6.0 rliable-1.0.8 sb3-contrib-1.7.0a10 scikit-optimize-0.9.0 seaborn-0.12.1 setproctitle-1.3.2 shortuuid-1.0.11 snowballstemmer-2.2.0 sphinx-5.3.0 sphinx-autobuild-2021.3.14 sphinx-autodoc-typehints-1.19.5 sphinx-copybutton-0.5.1 sphinx-rtd-theme-1.1.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 sphinxcontrib.spelling-7.7.0 stable-baselines3-1.7.0a10 statsmodels-0.13.5 tabledata-1.3.0 tcolorpy-0.1.2 typepy-1.3.0 typing-inspect-0.8.0 wandb-0.13.7
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
# 1. We define the hyperparameters in `rl-baselines3-zoo/hyperparams/dqn.yml`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/hyperparameters.png" alt="DQN Hyperparameters">

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We run `train.py` and save the models on `logs` folder 📁

# %%
# !python train.py --verbose 0 --algo dqn --env SpaceInvadersNoFrameskip-v4 -f logs/
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 4248638377
# Loading hyperparameters from: /OpenMail/hf_rl_class/unit3/rl-baselines3-zoo/hyperparams/dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 400000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gamma', 0.99),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 200000),
#              ('n_timesteps', 10000000.0),
#              ('normalize', False),
#              ('optimize_memory_usage', True),
#              ('policy', 'CnnPolicy'),
#              ('replay_buffer_kwargs', {'handle_timeout_termination': False}),
#              ('target_update_interval', 30000),
#              ('train_freq', 4)])
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_5
# Eval num_timesteps=25000, episode_reward=127.00 +/- 47.39
# Episode length: 2027.60 +/- 484.28
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=123.00 +/- 85.48
# Episode length: 1962.40 +/- 516.04
# Eval num_timesteps=75000, episode_reward=131.00 +/- 58.34
# Episode length: 1723.20 +/- 357.30
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=160.00 +/- 69.79
# Episode length: 2317.20 +/- 426.16
# New best mean reward!
# Eval num_timesteps=125000, episode_reward=128.00 +/- 66.08
# Episode length: 2031.20 +/- 516.28
# Eval num_timesteps=150000, episode_reward=133.00 +/- 115.70
# Episode length: 1907.20 +/- 735.22
# Eval num_timesteps=175000, episode_reward=182.00 +/- 97.81
# Episode length: 2056.40 +/- 509.91
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=131.00 +/- 57.57
# Episode length: 1897.20 +/- 454.17
# Eval num_timesteps=225000, episode_reward=162.00 +/- 24.00
# Episode length: 2221.20 +/- 554.38
# Eval num_timesteps=250000, episode_reward=184.00 +/- 71.37
# Episode length: 2197.60 +/- 586.44
# New best mean reward!
# Eval num_timesteps=275000, episode_reward=180.00 +/- 130.12
# Episode length: 2340.40 +/- 531.76
# Eval num_timesteps=300000, episode_reward=147.00 +/- 102.94
# Episode length: 2047.60 +/- 803.75
# Eval num_timesteps=325000, episode_reward=114.00 +/- 49.84
# Episode length: 2031.20 +/- 384.38
# Eval num_timesteps=350000, episode_reward=129.00 +/- 18.81
# Episode length: 2127.60 +/- 151.68
# Eval num_timesteps=375000, episode_reward=239.00 +/- 137.42
# Episode length: 2489.80 +/- 1026.45
# New best mean reward!
# Eval num_timesteps=400000, episode_reward=163.00 +/- 94.79
# Episode length: 2228.40 +/- 744.28
# Eval num_timesteps=425000, episode_reward=104.00 +/- 58.00
# Episode length: 1536.00 +/- 317.21
# Eval num_timesteps=450000, episode_reward=192.00 +/- 133.74
# Episode length: 2043.60 +/- 747.92
# Eval num_timesteps=475000, episode_reward=79.00 +/- 55.80
# Episode length: 1430.40 +/- 408.61
# Eval num_timesteps=500000, episode_reward=146.00 +/- 37.60
# Episode length: 2133.20 +/- 133.98
# Eval num_timesteps=525000, episode_reward=134.00 +/- 49.13
# Episode length: 1916.40 +/- 441.62
# Eval num_timesteps=550000, episode_reward=202.00 +/- 107.73
# Episode length: 2310.60 +/- 810.15
# Eval num_timesteps=575000, episode_reward=228.00 +/- 94.95
# Episode length: 2118.00 +/- 577.60
# Eval num_timesteps=600000, episode_reward=212.00 +/- 103.52
# Episode length: 1987.20 +/- 888.41
# Eval num_timesteps=625000, episode_reward=171.00 +/- 39.04
# Episode length: 2154.00 +/- 504.90
# Eval num_timesteps=650000, episode_reward=302.00 +/- 115.39
# Episode length: 2336.80 +/- 542.21
# New best mean reward!
# Eval num_timesteps=675000, episode_reward=250.00 +/- 113.89
# Episode length: 2100.80 +/- 467.34
# Eval num_timesteps=700000, episode_reward=274.00 +/- 86.57
# Episode length: 2203.20 +/- 403.19
# Eval num_timesteps=725000, episode_reward=364.00 +/- 145.86
# Episode length: 2700.40 +/- 244.76
# New best mean reward!
# Eval num_timesteps=750000, episode_reward=338.00 +/- 146.38
# Episode length: 2129.20 +/- 432.70
# Eval num_timesteps=775000, episode_reward=391.00 +/- 153.47
# Episode length: 2854.00 +/- 604.11
# New best mean reward!
# Eval num_timesteps=800000, episode_reward=267.00 +/- 154.23
# Episode length: 2124.20 +/- 596.83
# Eval num_timesteps=825000, episode_reward=321.00 +/- 50.04
# Episode length: 2274.00 +/- 268.17
# Eval num_timesteps=850000, episode_reward=242.00 +/- 81.22
# Episode length: 2259.20 +/- 718.23
# Eval num_timesteps=875000, episode_reward=322.00 +/- 113.25
# Episode length: 2557.20 +/- 698.44
# Eval num_timesteps=900000, episode_reward=316.00 +/- 100.12
# Episode length: 2341.60 +/- 640.30
# Eval num_timesteps=925000, episode_reward=415.00 +/- 143.70
# Episode length: 3067.20 +/- 594.68
# New best mean reward!
# Eval num_timesteps=950000, episode_reward=278.00 +/- 79.28
# Episode length: 1978.80 +/- 338.32
# Eval num_timesteps=975000, episode_reward=508.00 +/- 129.95
# Episode length: 3088.80 +/- 696.02
# New best mean reward!
# Eval num_timesteps=1000000, episode_reward=401.00 +/- 132.11
# Episode length: 2398.80 +/- 500.61
# Eval num_timesteps=1025000, episode_reward=515.00 +/- 256.09
# Episode length: 2715.20 +/- 789.16
# New best mean reward!
# Eval num_timesteps=1050000, episode_reward=342.00 +/- 129.29
# Episode length: 2269.20 +/- 776.18
# Eval num_timesteps=1075000, episode_reward=300.00 +/- 112.21
# Episode length: 2175.60 +/- 576.84
# Eval num_timesteps=1100000, episode_reward=380.00 +/- 98.94
# Episode length: 2723.60 +/- 655.52
# Eval num_timesteps=1125000, episode_reward=357.00 +/- 141.41
# Episode length: 2357.40 +/- 788.19
# Eval num_timesteps=1150000, episode_reward=380.00 +/- 170.21
# Episode length: 2190.40 +/- 454.07
# Eval num_timesteps=1175000, episode_reward=277.00 +/- 125.08
# Episode length: 1960.40 +/- 561.26
# Eval num_timesteps=1200000, episode_reward=492.00 +/- 162.50
# Episode length: 2686.20 +/- 529.60
# Eval num_timesteps=1225000, episode_reward=334.00 +/- 112.04
# Episode length: 2314.60 +/- 642.31
# Eval num_timesteps=1250000, episode_reward=301.00 +/- 105.71
# Episode length: 2346.00 +/- 530.10
# Eval num_timesteps=1275000, episode_reward=430.00 +/- 120.58
# Episode length: 2479.20 +/- 272.28
# Eval num_timesteps=1300000, episode_reward=340.00 +/- 82.52
# Episode length: 2021.60 +/- 461.94
# Eval num_timesteps=1325000, episode_reward=423.00 +/- 109.94
# Episode length: 2579.60 +/- 627.74
# Eval num_timesteps=1350000, episode_reward=439.00 +/- 98.05
# Episode length: 2659.20 +/- 621.84
# Eval num_timesteps=1375000, episode_reward=637.00 +/- 122.87
# Episode length: 3519.00 +/- 371.09
# New best mean reward!
# Eval num_timesteps=1400000, episode_reward=343.00 +/- 106.24
# Episode length: 2150.80 +/- 445.40
# Eval num_timesteps=1425000, episode_reward=443.00 +/- 83.16
# Episode length: 2459.60 +/- 633.55
# Eval num_timesteps=1450000, episode_reward=523.00 +/- 126.51
# Episode length: 3284.80 +/- 643.48
# Eval num_timesteps=1475000, episode_reward=439.00 +/- 116.76
# Episode length: 2623.60 +/- 472.04
# Eval num_timesteps=1500000, episode_reward=352.00 +/- 152.53
# Episode length: 2103.60 +/- 768.40
# Eval num_timesteps=1525000, episode_reward=512.00 +/- 107.55
# Episode length: 3095.60 +/- 506.22
# Eval num_timesteps=1550000, episode_reward=638.00 +/- 81.34
# Episode length: 3606.60 +/- 526.04
# New best mean reward!
# Eval num_timesteps=1575000, episode_reward=649.00 +/- 93.08
# Episode length: 3272.60 +/- 286.04
# New best mean reward!
# Eval num_timesteps=1600000, episode_reward=607.00 +/- 100.38
# Episode length: 3610.80 +/- 829.61
# Eval num_timesteps=1625000, episode_reward=610.00 +/- 105.45
# Episode length: 3266.80 +/- 310.07
# Eval num_timesteps=1650000, episode_reward=534.00 +/- 121.51
# Episode length: 2745.60 +/- 464.86
# Eval num_timesteps=1675000, episode_reward=436.00 +/- 118.72
# Episode length: 2835.20 +/- 876.82
# Eval num_timesteps=1700000, episode_reward=601.00 +/- 141.93
# Episode length: 3821.60 +/- 808.68
# Eval num_timesteps=1725000, episode_reward=546.00 +/- 47.05
# Episode length: 3214.60 +/- 318.12
# Eval num_timesteps=1750000, episode_reward=576.00 +/- 119.14
# Episode length: 3030.40 +/- 542.67
# Eval num_timesteps=1775000, episode_reward=566.00 +/- 61.19
# Episode length: 3343.80 +/- 801.20
# Eval num_timesteps=1800000, episode_reward=777.00 +/- 254.47
# Episode length: 4136.20 +/- 1387.68
# New best mean reward!
# Eval num_timesteps=1825000, episode_reward=592.00 +/- 48.54
# Episode length: 3464.40 +/- 411.09
# Eval num_timesteps=1850000, episode_reward=585.00 +/- 54.50
# Episode length: 3138.00 +/- 462.08
# Eval num_timesteps=1875000, episode_reward=683.00 +/- 125.88
# Episode length: 4564.00 +/- 1175.16
# Eval num_timesteps=1900000, episode_reward=561.00 +/- 28.88
# Episode length: 3424.60 +/- 363.16
# Eval num_timesteps=1925000, episode_reward=496.00 +/- 105.99
# Episode length: 3205.40 +/- 863.85
# Eval num_timesteps=1950000, episode_reward=608.00 +/- 71.87
# Episode length: 3680.80 +/- 657.96
# Eval num_timesteps=1975000, episode_reward=829.00 +/- 268.91
# Episode length: 4411.00 +/- 1490.21
# New best mean reward!
# Eval num_timesteps=2000000, episode_reward=893.00 +/- 206.41
# Episode length: 5167.20 +/- 1246.83
# New best mean reward!
# Eval num_timesteps=2025000, episode_reward=668.00 +/- 164.88
# Episode length: 4022.40 +/- 1413.29
# Eval num_timesteps=2050000, episode_reward=643.00 +/- 168.87
# Episode length: 3821.20 +/- 867.63
# Eval num_timesteps=2075000, episode_reward=618.00 +/- 78.65
# Episode length: 3427.40 +/- 359.15
# Eval num_timesteps=2100000, episode_reward=835.00 +/- 329.35
# Episode length: 4072.60 +/- 1543.61
# Eval num_timesteps=2125000, episode_reward=744.00 +/- 181.26
# Episode length: 4526.40 +/- 1500.72
# Eval num_timesteps=2150000, episode_reward=768.00 +/- 248.73
# Episode length: 4865.60 +/- 1219.95
# Eval num_timesteps=2175000, episode_reward=695.00 +/- 153.85
# Episode length: 4221.80 +/- 1361.01
# Eval num_timesteps=2200000, episode_reward=655.00 +/- 186.33
# Episode length: 3647.40 +/- 1509.76
# Eval num_timesteps=2225000, episode_reward=812.00 +/- 227.57
# Episode length: 3935.60 +/- 1603.81
# Eval num_timesteps=2250000, episode_reward=697.00 +/- 149.52
# Episode length: 4338.20 +/- 1517.51
# Eval num_timesteps=2275000, episode_reward=703.00 +/- 271.25
# Episode length: 4115.00 +/- 1624.43
# Eval num_timesteps=2300000, episode_reward=622.00 +/- 300.63
# Episode length: 3435.00 +/- 1247.24
# Eval num_timesteps=2325000, episode_reward=663.00 +/- 211.25
# Episode length: 4380.80 +/- 1789.28
# Eval num_timesteps=2350000, episode_reward=602.00 +/- 94.05
# Episode length: 3159.40 +/- 256.25
# Eval num_timesteps=2375000, episode_reward=880.00 +/- 268.53
# Episode length: 4090.40 +/- 1369.33
# Eval num_timesteps=2400000, episode_reward=658.00 +/- 95.63
# Episode length: 3382.20 +/- 280.51
# Eval num_timesteps=2425000, episode_reward=815.00 +/- 197.79
# Episode length: 4760.80 +/- 1086.43
# Eval num_timesteps=2450000, episode_reward=688.00 +/- 155.45
# Episode length: 3858.00 +/- 927.82
# Eval num_timesteps=2475000, episode_reward=707.00 +/- 240.64
# Episode length: 4372.20 +/- 1370.34
# Eval num_timesteps=2500000, episode_reward=573.00 +/- 131.97
# Episode length: 3392.00 +/- 656.23
# Eval num_timesteps=2525000, episode_reward=899.00 +/- 337.97
# Episode length: 4604.40 +/- 1602.19
# New best mean reward!
# Eval num_timesteps=2550000, episode_reward=572.00 +/- 151.48
# Episode length: 3034.00 +/- 553.85
# Eval num_timesteps=2575000, episode_reward=644.00 +/- 80.71
# Episode length: 3081.20 +/- 273.90
# Eval num_timesteps=2600000, episode_reward=593.00 +/- 106.28
# Episode length: 3042.40 +/- 390.28
# Eval num_timesteps=2625000, episode_reward=806.00 +/- 61.92
# Episode length: 3748.60 +/- 692.79
# Eval num_timesteps=2650000, episode_reward=764.00 +/- 225.91
# Episode length: 4066.80 +/- 1101.80
# Eval num_timesteps=2675000, episode_reward=1027.00 +/- 345.54
# Episode length: 5120.40 +/- 1589.57
# New best mean reward!
# Eval num_timesteps=2700000, episode_reward=950.00 +/- 235.20
# Episode length: 5297.80 +/- 1563.42
# Eval num_timesteps=2725000, episode_reward=680.00 +/- 217.37
# Episode length: 4233.60 +/- 1619.10
# Eval num_timesteps=2750000, episode_reward=1012.00 +/- 261.47
# Episode length: 5690.80 +/- 1442.59
# Eval num_timesteps=2775000, episode_reward=680.00 +/- 376.59
# Episode length: 3774.80 +/- 2090.77
# Eval num_timesteps=2800000, episode_reward=682.00 +/- 137.03
# Episode length: 3712.20 +/- 896.94
# Eval num_timesteps=2825000, episode_reward=939.00 +/- 216.90
# Episode length: 4962.80 +/- 1491.98
# Eval num_timesteps=2850000, episode_reward=900.00 +/- 320.09
# Episode length: 4559.20 +/- 1035.88
# Eval num_timesteps=2875000, episode_reward=689.00 +/- 205.87
# Episode length: 4032.60 +/- 1717.74
# Eval num_timesteps=2900000, episode_reward=694.00 +/- 153.80
# Episode length: 3425.20 +/- 1107.95
# Eval num_timesteps=2925000, episode_reward=999.00 +/- 176.08
# Episode length: 5708.40 +/- 1388.47
# Eval num_timesteps=2950000, episode_reward=1235.00 +/- 592.71
# Episode length: 6033.60 +/- 2747.77
# New best mean reward!
# Eval num_timesteps=2975000, episode_reward=782.00 +/- 262.31
# Episode length: 3905.60 +/- 1352.48
# Eval num_timesteps=3000000, episode_reward=795.00 +/- 311.06
# Episode length: 4435.40 +/- 1704.28
# Eval num_timesteps=3025000, episode_reward=888.00 +/- 412.80
# Episode length: 4833.20 +/- 1804.57
# Eval num_timesteps=3050000, episode_reward=826.00 +/- 276.95
# Episode length: 4765.40 +/- 1647.99
# Eval num_timesteps=3075000, episode_reward=704.00 +/- 256.85
# Episode length: 4598.40 +/- 1431.10
# Eval num_timesteps=3100000, episode_reward=629.00 +/- 88.11
# Episode length: 3136.80 +/- 234.35
# Eval num_timesteps=3125000, episode_reward=997.00 +/- 436.11
# Episode length: 5461.60 +/- 1605.65
# Eval num_timesteps=3150000, episode_reward=882.00 +/- 287.24
# Episode length: 4359.20 +/- 1450.71
# Eval num_timesteps=3175000, episode_reward=1001.00 +/- 230.88
# Episode length: 5026.60 +/- 1702.21
# Eval num_timesteps=3200000, episode_reward=813.00 +/- 288.75
# Episode length: 4353.40 +/- 1944.34
# Eval num_timesteps=3225000, episode_reward=580.00 +/- 225.30
# Episode length: 3523.60 +/- 1146.66
# Eval num_timesteps=3250000, episode_reward=965.00 +/- 300.27
# Episode length: 5281.20 +/- 1811.44
# Eval num_timesteps=3275000, episode_reward=1000.00 +/- 306.99
# Episode length: 4954.00 +/- 1781.47
# Eval num_timesteps=3300000, episode_reward=622.00 +/- 77.56
# Episode length: 3250.80 +/- 154.26
# Eval num_timesteps=3325000, episode_reward=779.00 +/- 115.69
# Episode length: 3443.60 +/- 414.51
# Eval num_timesteps=3350000, episode_reward=851.00 +/- 226.55
# Episode length: 4869.20 +/- 1363.37
# Eval num_timesteps=3375000, episode_reward=776.00 +/- 99.07
# Episode length: 3727.00 +/- 975.38
# Eval num_timesteps=3400000, episode_reward=1056.00 +/- 166.84
# Episode length: 5612.40 +/- 1230.12
# Eval num_timesteps=3425000, episode_reward=936.00 +/- 332.08
# Episode length: 4681.20 +/- 1746.54
# Eval num_timesteps=3450000, episode_reward=914.00 +/- 300.01
# Episode length: 4931.20 +/- 1788.83
# Eval num_timesteps=3475000, episode_reward=665.00 +/- 94.13
# Episode length: 2835.00 +/- 232.30
# Eval num_timesteps=3500000, episode_reward=770.00 +/- 269.72
# Episode length: 4071.40 +/- 1298.90
# Eval num_timesteps=3525000, episode_reward=1011.00 +/- 361.79
# Episode length: 4424.00 +/- 1182.56
# Eval num_timesteps=3550000, episode_reward=752.00 +/- 316.65
# Episode length: 4227.80 +/- 1495.32
# Eval num_timesteps=3575000, episode_reward=693.00 +/- 186.00
# Episode length: 4282.80 +/- 1790.71
# Eval num_timesteps=3600000, episode_reward=732.00 +/- 306.70
# Episode length: 3910.80 +/- 1345.42
# Eval num_timesteps=3625000, episode_reward=961.00 +/- 300.34
# Episode length: 5184.00 +/- 1625.89
# Eval num_timesteps=3650000, episode_reward=970.00 +/- 283.14
# Episode length: 4996.20 +/- 1645.17
# Eval num_timesteps=3675000, episode_reward=705.00 +/- 263.08
# Episode length: 3670.40 +/- 1194.34
# Eval num_timesteps=3700000, episode_reward=1067.00 +/- 319.34
# Episode length: 5833.60 +/- 1470.66
# Eval num_timesteps=3725000, episode_reward=882.00 +/- 285.23
# Episode length: 4774.20 +/- 2077.17
# Eval num_timesteps=3750000, episode_reward=1202.00 +/- 215.33
# Episode length: 5976.60 +/- 423.25
# Eval num_timesteps=3775000, episode_reward=922.00 +/- 359.12
# Episode length: 4663.40 +/- 1659.44
# Eval num_timesteps=3800000, episode_reward=949.00 +/- 227.85
# Episode length: 5393.20 +/- 1510.73
# Eval num_timesteps=3825000, episode_reward=1052.00 +/- 268.02
# Episode length: 4922.00 +/- 1558.02
# Eval num_timesteps=3850000, episode_reward=887.00 +/- 387.42
# Episode length: 4251.40 +/- 1864.65
# Eval num_timesteps=3875000, episode_reward=1086.00 +/- 412.86
# Episode length: 5688.40 +/- 1471.76
# Eval num_timesteps=3900000, episode_reward=934.00 +/- 295.17
# Episode length: 5332.00 +/- 1451.85
# Eval num_timesteps=3925000, episode_reward=726.00 +/- 299.84
# Episode length: 3894.20 +/- 1209.64
# Eval num_timesteps=3950000, episode_reward=1209.00 +/- 466.67
# Episode length: 6164.20 +/- 2069.20
# Eval num_timesteps=3975000, episode_reward=1226.00 +/- 353.06
# Episode length: 6396.40 +/- 1428.82
# Eval num_timesteps=4000000, episode_reward=953.00 +/- 325.62
# Episode length: 4571.80 +/- 1375.38
# Eval num_timesteps=4025000, episode_reward=1249.00 +/- 190.88
# Episode length: 6635.40 +/- 266.85
# New best mean reward!
# Eval num_timesteps=4050000, episode_reward=1064.00 +/- 338.22
# Episode length: 5058.20 +/- 1243.06
# Eval num_timesteps=4075000, episode_reward=954.00 +/- 292.43
# Episode length: 4655.80 +/- 1181.36
# Eval num_timesteps=4100000, episode_reward=995.00 +/- 363.57
# Episode length: 5447.00 +/- 1947.11
# Eval num_timesteps=4125000, episode_reward=603.00 +/- 55.64
# Episode length: 3700.80 +/- 470.14
# Eval num_timesteps=4150000, episode_reward=842.00 +/- 285.33
# Episode length: 4078.20 +/- 1339.37
# Eval num_timesteps=4175000, episode_reward=894.00 +/- 210.27
# Episode length: 4582.00 +/- 1524.26
# Eval num_timesteps=4200000, episode_reward=862.00 +/- 349.98
# Episode length: 4243.40 +/- 1183.03
# Eval num_timesteps=4225000, episode_reward=843.00 +/- 363.93
# Episode length: 4288.00 +/- 1628.16
# Eval num_timesteps=4250000, episode_reward=838.00 +/- 327.30
# Episode length: 4435.20 +/- 1538.48
# Eval num_timesteps=4275000, episode_reward=914.00 +/- 374.77
# Episode length: 4149.00 +/- 1606.83
# Eval num_timesteps=4300000, episode_reward=1025.00 +/- 293.80
# Episode length: 5187.20 +/- 1155.66
# Eval num_timesteps=4325000, episode_reward=693.00 +/- 213.86
# Episode length: 3795.80 +/- 1255.75
# Eval num_timesteps=4350000, episode_reward=778.00 +/- 206.82
# Episode length: 3590.80 +/- 1178.65
# Eval num_timesteps=4375000, episode_reward=859.00 +/- 277.57
# Episode length: 4392.80 +/- 1687.24
# Eval num_timesteps=4400000, episode_reward=1039.00 +/- 395.64
# Episode length: 4419.80 +/- 1770.36
# Eval num_timesteps=4425000, episode_reward=1107.00 +/- 168.07
# Episode length: 5811.60 +/- 1260.13
# Eval num_timesteps=4450000, episode_reward=864.00 +/- 351.22
# Episode length: 4663.60 +/- 1612.42
# Eval num_timesteps=4475000, episode_reward=1395.00 +/- 473.30
# Episode length: 6748.80 +/- 2658.04
# New best mean reward!
# Eval num_timesteps=4500000, episode_reward=1061.00 +/- 562.42
# Episode length: 5048.20 +/- 2794.10
# Eval num_timesteps=4525000, episode_reward=764.00 +/- 244.12
# Episode length: 4339.60 +/- 1466.70
# Eval num_timesteps=4550000, episode_reward=907.00 +/- 251.17
# Episode length: 5358.80 +/- 1123.97
# Eval num_timesteps=4575000, episode_reward=1014.00 +/- 323.39
# Episode length: 4872.20 +/- 1269.22
# Eval num_timesteps=4600000, episode_reward=1466.00 +/- 621.93
# Episode length: 6557.20 +/- 3146.65
# New best mean reward!
# Eval num_timesteps=4625000, episode_reward=1130.00 +/- 475.36
# Episode length: 5463.40 +/- 1889.16
# Eval num_timesteps=4650000, episode_reward=1053.00 +/- 410.71
# Episode length: 5326.60 +/- 1726.79
# Eval num_timesteps=4675000, episode_reward=1145.00 +/- 349.27
# Episode length: 5647.40 +/- 1289.65
# Eval num_timesteps=4700000, episode_reward=1061.00 +/- 386.40
# Episode length: 4828.60 +/- 1295.31
# Eval num_timesteps=4725000, episode_reward=688.00 +/- 201.46
# Episode length: 3881.20 +/- 1153.32
# Eval num_timesteps=4750000, episode_reward=856.00 +/- 380.85
# Episode length: 4306.60 +/- 1538.87
# Eval num_timesteps=4775000, episode_reward=752.00 +/- 293.17
# Episode length: 4268.40 +/- 1533.24
# Eval num_timesteps=4800000, episode_reward=1033.00 +/- 237.33
# Episode length: 5546.60 +/- 1348.19
# Eval num_timesteps=4825000, episode_reward=573.00 +/- 23.58
# Episode length: 3348.40 +/- 287.76
# Eval num_timesteps=4850000, episode_reward=999.00 +/- 476.17
# Episode length: 5440.00 +/- 2609.98
# Eval num_timesteps=4875000, episode_reward=761.00 +/- 313.17
# Episode length: 4066.20 +/- 1095.46
# Eval num_timesteps=4900000, episode_reward=824.00 +/- 285.23
# Episode length: 4298.80 +/- 1169.78
# Eval num_timesteps=4925000, episode_reward=874.00 +/- 251.62
# Episode length: 5013.60 +/- 1632.62
# Eval num_timesteps=4950000, episode_reward=1104.00 +/- 275.82
# Episode length: 5661.60 +/- 1388.45
# Eval num_timesteps=4975000, episode_reward=1076.00 +/- 266.41
# Episode length: 5798.20 +/- 1507.34
# Eval num_timesteps=5000000, episode_reward=772.00 +/- 317.06
# Episode length: 3562.40 +/- 1154.64
# Eval num_timesteps=5025000, episode_reward=1134.00 +/- 304.14
# Episode length: 5883.20 +/- 1651.70
# Eval num_timesteps=5050000, episode_reward=897.00 +/- 256.94
# Episode length: 4728.00 +/- 1426.64
# Eval num_timesteps=5075000, episode_reward=851.00 +/- 363.47
# Episode length: 4367.80 +/- 1505.87
# Eval num_timesteps=5100000, episode_reward=927.00 +/- 289.34
# Episode length: 5088.00 +/- 1687.57
# Eval num_timesteps=5125000, episode_reward=918.00 +/- 265.53
# Episode length: 4460.20 +/- 1340.22
# Eval num_timesteps=5150000, episode_reward=888.00 +/- 256.96
# Episode length: 5093.20 +/- 1701.67
# Eval num_timesteps=5175000, episode_reward=1127.00 +/- 504.51
# Episode length: 5691.80 +/- 2828.12
# Eval num_timesteps=5200000, episode_reward=842.00 +/- 301.82
# Episode length: 3911.20 +/- 1193.58
# Eval num_timesteps=5225000, episode_reward=889.00 +/- 395.47
# Episode length: 4340.40 +/- 2196.12
# Eval num_timesteps=5250000, episode_reward=918.00 +/- 314.91
# Episode length: 4592.00 +/- 1835.30
# Eval num_timesteps=5275000, episode_reward=891.00 +/- 347.40
# Episode length: 4480.60 +/- 1732.85
# Eval num_timesteps=5300000, episode_reward=1028.00 +/- 253.45
# Episode length: 5288.20 +/- 1297.05
# Eval num_timesteps=5325000, episode_reward=1137.00 +/- 446.35
# Episode length: 5745.20 +/- 1940.96
# Eval num_timesteps=5350000, episode_reward=1205.00 +/- 455.38
# Episode length: 6205.60 +/- 1881.07
# Eval num_timesteps=5375000, episode_reward=932.00 +/- 291.44
# Episode length: 4121.60 +/- 1552.86
# Eval num_timesteps=5400000, episode_reward=697.00 +/- 267.35
# Episode length: 3738.40 +/- 1256.94
# Eval num_timesteps=5425000, episode_reward=899.00 +/- 386.24
# Episode length: 4519.40 +/- 1537.89
# Eval num_timesteps=5450000, episode_reward=1143.00 +/- 564.66
# Episode length: 5458.60 +/- 2110.94
# Eval num_timesteps=5475000, episode_reward=847.00 +/- 290.01
# Episode length: 3984.40 +/- 1442.89
# Eval num_timesteps=5500000, episode_reward=842.00 +/- 329.61
# Episode length: 4396.80 +/- 1444.58
# Eval num_timesteps=5525000, episode_reward=794.00 +/- 307.50
# Episode length: 4543.60 +/- 1420.57
# Eval num_timesteps=5550000, episode_reward=826.00 +/- 428.30
# Episode length: 3937.00 +/- 1700.92
# Eval num_timesteps=5575000, episode_reward=940.00 +/- 348.96
# Episode length: 4916.00 +/- 1802.17
# Eval num_timesteps=5600000, episode_reward=989.00 +/- 342.91
# Episode length: 4632.80 +/- 1267.16
# Eval num_timesteps=5625000, episode_reward=1094.00 +/- 423.95
# Episode length: 5715.60 +/- 2171.49
# Eval num_timesteps=5650000, episode_reward=779.00 +/- 342.39
# Episode length: 4144.80 +/- 1723.84
# Eval num_timesteps=5675000, episode_reward=792.00 +/- 276.49
# Episode length: 3966.60 +/- 1294.14
# Eval num_timesteps=5700000, episode_reward=928.00 +/- 293.68
# Episode length: 4666.40 +/- 1507.67
# Eval num_timesteps=5725000, episode_reward=1203.00 +/- 61.04
# Episode length: 6209.60 +/- 363.09
# Eval num_timesteps=5750000, episode_reward=1149.00 +/- 506.24
# Episode length: 5686.60 +/- 1938.10
# Eval num_timesteps=5775000, episode_reward=859.00 +/- 375.70
# Episode length: 4284.80 +/- 1607.32
# Eval num_timesteps=5800000, episode_reward=1049.00 +/- 226.48
# Episode length: 5239.40 +/- 1015.10
# Eval num_timesteps=5825000, episode_reward=1111.00 +/- 111.60
# Episode length: 5860.60 +/- 609.80
# Eval num_timesteps=5850000, episode_reward=1110.00 +/- 462.72
# Episode length: 5647.80 +/- 1450.21
# Eval num_timesteps=5875000, episode_reward=1065.00 +/- 270.68
# Episode length: 5434.40 +/- 1456.99
# Eval num_timesteps=5900000, episode_reward=1199.00 +/- 535.01
# Episode length: 5716.80 +/- 1751.60
# Eval num_timesteps=5925000, episode_reward=941.00 +/- 399.62
# Episode length: 4237.80 +/- 1863.91
# Eval num_timesteps=5950000, episode_reward=1030.00 +/- 427.98
# Episode length: 5785.20 +/- 2423.31
# Eval num_timesteps=5975000, episode_reward=716.00 +/- 328.14
# Episode length: 3458.40 +/- 1246.43
# Eval num_timesteps=6000000, episode_reward=1020.00 +/- 410.28
# Episode length: 5317.00 +/- 1736.75
# Eval num_timesteps=6025000, episode_reward=567.00 +/- 43.20
# Episode length: 3398.80 +/- 176.00
# Eval num_timesteps=6050000, episode_reward=980.00 +/- 359.89
# Episode length: 4816.80 +/- 1893.24
# Eval num_timesteps=6075000, episode_reward=894.00 +/- 327.56
# Episode length: 4437.80 +/- 1610.91
# Eval num_timesteps=6100000, episode_reward=897.00 +/- 445.16
# Episode length: 5208.20 +/- 2274.45
# Eval num_timesteps=6125000, episode_reward=1015.00 +/- 237.02
# Episode length: 5519.80 +/- 1307.30
# Eval num_timesteps=6150000, episode_reward=1065.00 +/- 233.47
# Episode length: 5315.80 +/- 1142.90
# Eval num_timesteps=6175000, episode_reward=1030.00 +/- 385.89
# Episode length: 4927.80 +/- 1257.85
# Eval num_timesteps=6200000, episode_reward=998.00 +/- 218.90
# Episode length: 5624.60 +/- 1223.72
# Eval num_timesteps=6225000, episode_reward=1303.00 +/- 94.37
# Episode length: 6567.40 +/- 452.39
# Eval num_timesteps=6250000, episode_reward=922.00 +/- 453.78
# Episode length: 4430.20 +/- 1932.50
# Eval num_timesteps=6275000, episode_reward=1362.00 +/- 677.01
# Episode length: 6668.80 +/- 3202.82
# Eval num_timesteps=6300000, episode_reward=1184.00 +/- 32.62
# Episode length: 6141.80 +/- 828.67
# Eval num_timesteps=6325000, episode_reward=974.00 +/- 531.21
# Episode length: 4722.60 +/- 2368.16
# Eval num_timesteps=6350000, episode_reward=1207.00 +/- 384.98
# Episode length: 5831.80 +/- 2006.49
# Eval num_timesteps=6375000, episode_reward=1178.00 +/- 395.90
# Episode length: 6087.20 +/- 1665.61
# Eval num_timesteps=6400000, episode_reward=1437.00 +/- 518.64
# Episode length: 6562.00 +/- 2015.74
# Eval num_timesteps=6425000, episode_reward=1021.00 +/- 533.92
# Episode length: 4562.60 +/- 2302.77
# Eval num_timesteps=6450000, episode_reward=1513.00 +/- 259.55
# Episode length: 7348.40 +/- 1203.70
# New best mean reward!
# Eval num_timesteps=6475000, episode_reward=1007.00 +/- 356.46
# Episode length: 5306.60 +/- 1438.86
# Eval num_timesteps=6500000, episode_reward=1143.00 +/- 397.85
# Episode length: 5364.40 +/- 1989.81
# Eval num_timesteps=6525000, episode_reward=898.00 +/- 339.63
# Episode length: 4359.00 +/- 1425.21
# Eval num_timesteps=6550000, episode_reward=1089.00 +/- 473.42
# Episode length: 5593.40 +/- 1937.68
# Eval num_timesteps=6575000, episode_reward=1205.00 +/- 351.87
# Episode length: 6080.00 +/- 1566.37
# Eval num_timesteps=6600000, episode_reward=1065.00 +/- 245.28
# Episode length: 5517.80 +/- 1449.50
# Eval num_timesteps=6625000, episode_reward=788.00 +/- 303.98
# Episode length: 4025.00 +/- 1364.24
# Eval num_timesteps=6650000, episode_reward=1217.00 +/- 396.81
# Episode length: 6547.80 +/- 1606.05
# Eval num_timesteps=6675000, episode_reward=1228.00 +/- 594.47
# Episode length: 5733.40 +/- 2966.82
# Eval num_timesteps=6700000, episode_reward=885.00 +/- 246.13
# Episode length: 4667.60 +/- 1188.56
# Eval num_timesteps=6725000, episode_reward=671.00 +/- 257.59
# Episode length: 3936.00 +/- 1154.99
# Eval num_timesteps=6750000, episode_reward=1033.00 +/- 287.93
# Episode length: 4469.40 +/- 1620.36
# Eval num_timesteps=6775000, episode_reward=1168.00 +/- 182.77
# Episode length: 6029.60 +/- 631.56
# Eval num_timesteps=6800000, episode_reward=1158.00 +/- 590.37
# Episode length: 5517.00 +/- 2487.48
# Eval num_timesteps=6825000, episode_reward=862.00 +/- 304.36
# Episode length: 4404.40 +/- 1414.98
# Eval num_timesteps=6850000, episode_reward=946.00 +/- 399.48
# Episode length: 4716.40 +/- 1219.73
# Eval num_timesteps=6875000, episode_reward=1199.00 +/- 290.64
# Episode length: 6018.00 +/- 1184.92
# Eval num_timesteps=6900000, episode_reward=1011.00 +/- 493.05
# Episode length: 5087.60 +/- 2110.47
# Eval num_timesteps=6925000, episode_reward=878.00 +/- 314.72
# Episode length: 4163.00 +/- 1556.10
# Eval num_timesteps=6950000, episode_reward=957.00 +/- 335.82
# Episode length: 4474.00 +/- 1590.49
# Eval num_timesteps=6975000, episode_reward=1305.00 +/- 359.85
# Episode length: 6153.60 +/- 1565.52
# Eval num_timesteps=7000000, episode_reward=1057.00 +/- 441.73
# Episode length: 5375.00 +/- 2132.82
# Eval num_timesteps=7025000, episode_reward=1399.00 +/- 580.03
# Episode length: 6765.80 +/- 2761.68
# Eval num_timesteps=7050000, episode_reward=1023.00 +/- 567.28
# Episode length: 4812.80 +/- 2412.00
# Eval num_timesteps=7075000, episode_reward=1071.00 +/- 357.62
# Episode length: 5412.60 +/- 1624.14
# Eval num_timesteps=7100000, episode_reward=962.00 +/- 381.77
# Episode length: 5012.80 +/- 1242.75
# Eval num_timesteps=7125000, episode_reward=850.00 +/- 361.36
# Episode length: 4367.20 +/- 1597.88
# Eval num_timesteps=7150000, episode_reward=1178.00 +/- 502.67
# Episode length: 5614.80 +/- 2063.89
# Eval num_timesteps=7175000, episode_reward=1165.00 +/- 624.52
# Episode length: 5587.20 +/- 2332.15
# Eval num_timesteps=7200000, episode_reward=1131.00 +/- 240.09
# Episode length: 5094.60 +/- 1213.58
# Eval num_timesteps=7225000, episode_reward=996.00 +/- 454.13
# Episode length: 5343.00 +/- 2622.42
# Eval num_timesteps=7250000, episode_reward=1102.00 +/- 393.52
# Episode length: 5321.60 +/- 1665.69
# Eval num_timesteps=7275000, episode_reward=1175.00 +/- 683.06
# Episode length: 5562.60 +/- 3041.51
# Eval num_timesteps=7300000, episode_reward=1605.00 +/- 411.56
# Episode length: 7484.40 +/- 1481.69
# New best mean reward!
# Eval num_timesteps=7325000, episode_reward=1113.00 +/- 268.80
# Episode length: 5203.80 +/- 1326.70
# Eval num_timesteps=7350000, episode_reward=954.00 +/- 320.46
# Episode length: 4826.60 +/- 1366.93
# Eval num_timesteps=7375000, episode_reward=975.00 +/- 270.37
# Episode length: 5386.80 +/- 1285.70
# Eval num_timesteps=7400000, episode_reward=1082.00 +/- 181.62
# Episode length: 5712.60 +/- 1013.19
# Eval num_timesteps=7425000, episode_reward=1550.00 +/- 632.37
# Episode length: 7177.20 +/- 1994.71
# Eval num_timesteps=7450000, episode_reward=1408.00 +/- 586.74
# Episode length: 7273.80 +/- 2177.12
# Eval num_timesteps=7475000, episode_reward=1220.00 +/- 385.16
# Episode length: 5687.80 +/- 1482.52
# Eval num_timesteps=7500000, episode_reward=1150.00 +/- 66.26
# Episode length: 5597.00 +/- 242.78
# Eval num_timesteps=7525000, episode_reward=1357.00 +/- 718.54
# Episode length: 7218.60 +/- 2916.07
# Eval num_timesteps=7550000, episode_reward=1023.00 +/- 227.83
# Episode length: 5281.20 +/- 916.49
# Eval num_timesteps=7575000, episode_reward=1386.00 +/- 417.41
# Episode length: 7298.40 +/- 2278.87
# Eval num_timesteps=7600000, episode_reward=1203.00 +/- 24.00
# Episode length: 5967.60 +/- 508.19
# Eval num_timesteps=7625000, episode_reward=678.00 +/- 266.83
# Episode length: 3743.00 +/- 1233.24
# Eval num_timesteps=7650000, episode_reward=1312.00 +/- 706.34
# Episode length: 5984.00 +/- 3227.78
# Eval num_timesteps=7675000, episode_reward=1283.00 +/- 327.15
# Episode length: 6213.00 +/- 2029.68
# Eval num_timesteps=7700000, episode_reward=1626.00 +/- 586.66
# Episode length: 8069.60 +/- 2694.84
# New best mean reward!
# Eval num_timesteps=7725000, episode_reward=998.00 +/- 261.89
# Episode length: 5405.80 +/- 1636.92
# Eval num_timesteps=7750000, episode_reward=837.00 +/- 247.16
# Episode length: 4324.00 +/- 1460.45
# Eval num_timesteps=7775000, episode_reward=1374.00 +/- 512.58
# Episode length: 6793.60 +/- 2782.62
# Eval num_timesteps=7800000, episode_reward=1456.00 +/- 455.31
# Episode length: 7066.00 +/- 1969.73
# Eval num_timesteps=7825000, episode_reward=1299.00 +/- 392.27
# Episode length: 6018.00 +/- 1451.80
# Eval num_timesteps=7850000, episode_reward=1131.00 +/- 675.44
# Episode length: 6253.40 +/- 3146.00
# Eval num_timesteps=7875000, episode_reward=1340.00 +/- 527.07
# Episode length: 6153.20 +/- 2598.21
# Eval num_timesteps=7900000, episode_reward=1326.00 +/- 541.26
# Episode length: 6343.40 +/- 2458.41
# Eval num_timesteps=7925000, episode_reward=711.00 +/- 147.83
# Episode length: 3604.60 +/- 822.87
# Eval num_timesteps=7950000, episode_reward=1102.00 +/- 287.53
# Episode length: 5491.20 +/- 1581.58
# Eval num_timesteps=7975000, episode_reward=1875.00 +/- 645.72
# Episode length: 8457.00 +/- 2262.73
# New best mean reward!
# Eval num_timesteps=8000000, episode_reward=1380.00 +/- 563.91
# Episode length: 6061.80 +/- 1840.45
# Eval num_timesteps=8025000, episode_reward=972.00 +/- 252.80
# Episode length: 5144.60 +/- 1704.34
# Eval num_timesteps=8050000, episode_reward=1042.00 +/- 464.84
# Episode length: 5116.40 +/- 2048.19
# Eval num_timesteps=8075000, episode_reward=1172.00 +/- 393.16
# Episode length: 5513.20 +/- 845.76
# Eval num_timesteps=8100000, episode_reward=1456.00 +/- 712.98
# Episode length: 7079.60 +/- 2921.11
# Eval num_timesteps=8125000, episode_reward=1450.00 +/- 384.20
# Episode length: 7248.20 +/- 1392.16
# Eval num_timesteps=8150000, episode_reward=739.00 +/- 389.25
# Episode length: 4131.20 +/- 1812.15
# Eval num_timesteps=8175000, episode_reward=1108.00 +/- 668.05
# Episode length: 5434.60 +/- 2848.19
# Eval num_timesteps=8200000, episode_reward=1425.00 +/- 551.82
# Episode length: 6574.00 +/- 2380.69
# Eval num_timesteps=8225000, episode_reward=1258.00 +/- 851.87
# Episode length: 5627.40 +/- 3354.90
# Eval num_timesteps=8250000, episode_reward=1139.00 +/- 496.85
# Episode length: 5529.60 +/- 1992.32
# Eval num_timesteps=8275000, episode_reward=1807.00 +/- 455.06
# Episode length: 8427.40 +/- 1739.51
# Eval num_timesteps=8300000, episode_reward=1186.00 +/- 649.70
# Episode length: 5556.00 +/- 2667.57
# Eval num_timesteps=8325000, episode_reward=2120.00 +/- 339.56
# Episode length: 10143.20 +/- 1899.14
# New best mean reward!
# Eval num_timesteps=8350000, episode_reward=1202.00 +/- 122.91
# Episode length: 6192.40 +/- 807.46
# Eval num_timesteps=8375000, episode_reward=1515.00 +/- 590.78
# Episode length: 7168.00 +/- 2636.02
# Eval num_timesteps=8400000, episode_reward=1593.00 +/- 694.81
# Episode length: 7517.00 +/- 2866.24
# Eval num_timesteps=8425000, episode_reward=1161.00 +/- 634.46
# Episode length: 5439.60 +/- 2570.72
# Eval num_timesteps=8450000, episode_reward=878.00 +/- 274.31
# Episode length: 4691.00 +/- 1394.12
# Eval num_timesteps=8475000, episode_reward=1279.00 +/- 676.12
# Episode length: 5710.80 +/- 2490.59
# Eval num_timesteps=8500000, episode_reward=2038.00 +/- 255.63
# Episode length: 9482.60 +/- 718.16
# Eval num_timesteps=8525000, episode_reward=1329.00 +/- 430.19
# Episode length: 6334.20 +/- 1979.32
# Eval num_timesteps=8550000, episode_reward=1047.00 +/- 291.18
# Episode length: 5378.80 +/- 1615.25
# Eval num_timesteps=8575000, episode_reward=1465.00 +/- 496.64
# Episode length: 6983.40 +/- 2157.38
# Eval num_timesteps=8600000, episode_reward=1894.00 +/- 542.54
# Episode length: 8598.60 +/- 2467.53
# Eval num_timesteps=8625000, episode_reward=827.00 +/- 333.46
# Episode length: 3834.80 +/- 1221.14
# Eval num_timesteps=8650000, episode_reward=1299.00 +/- 322.91
# Episode length: 6659.20 +/- 1159.18
# Eval num_timesteps=8675000, episode_reward=1250.00 +/- 456.53
# Episode length: 6415.00 +/- 1931.33
# Eval num_timesteps=8700000, episode_reward=1255.00 +/- 169.91
# Episode length: 5683.00 +/- 436.08
# Eval num_timesteps=8725000, episode_reward=1143.00 +/- 394.00
# Episode length: 6066.00 +/- 1790.53
# Eval num_timesteps=8750000, episode_reward=1079.00 +/- 281.09
# Episode length: 5589.80 +/- 1247.96
# Eval num_timesteps=8775000, episode_reward=1257.00 +/- 272.08
# Episode length: 5311.00 +/- 1108.39
# Eval num_timesteps=8800000, episode_reward=1185.00 +/- 507.40
# Episode length: 5416.00 +/- 1923.84
# Eval num_timesteps=8825000, episode_reward=1259.00 +/- 87.72
# Episode length: 6158.60 +/- 432.87
# Eval num_timesteps=8850000, episode_reward=859.00 +/- 306.60
# Episode length: 4249.60 +/- 1118.72
# Eval num_timesteps=8875000, episode_reward=1160.00 +/- 595.11
# Episode length: 5693.80 +/- 2615.16
# Eval num_timesteps=8900000, episode_reward=1366.00 +/- 557.83
# Episode length: 6913.20 +/- 2213.91
# Eval num_timesteps=8925000, episode_reward=1300.00 +/- 266.38
# Episode length: 6434.20 +/- 1121.32
# Eval num_timesteps=8950000, episode_reward=1678.00 +/- 829.35
# Episode length: 7408.40 +/- 2935.92
# Eval num_timesteps=8975000, episode_reward=1591.00 +/- 404.99
# Episode length: 7732.40 +/- 1575.20
# Eval num_timesteps=9000000, episode_reward=971.00 +/- 508.03
# Episode length: 4738.80 +/- 1946.40
# Eval num_timesteps=9025000, episode_reward=1773.00 +/- 520.95
# Episode length: 7934.40 +/- 2443.81
# Eval num_timesteps=9050000, episode_reward=1699.00 +/- 814.34
# Episode length: 7674.20 +/- 2952.25
# Eval num_timesteps=9075000, episode_reward=799.00 +/- 489.67
# Episode length: 3621.00 +/- 942.34
# Eval num_timesteps=9100000, episode_reward=1318.00 +/- 522.89
# Episode length: 5835.80 +/- 2140.94
# Eval num_timesteps=9125000, episode_reward=1240.00 +/- 530.67
# Episode length: 6127.20 +/- 2733.48
# Eval num_timesteps=9150000, episode_reward=1142.00 +/- 524.52
# Episode length: 5530.80 +/- 2564.97
# Eval num_timesteps=9175000, episode_reward=1574.00 +/- 1009.07
# Episode length: 7204.20 +/- 3927.78
# Eval num_timesteps=9200000, episode_reward=1251.00 +/- 784.94
# Episode length: 6372.00 +/- 3516.39
# Eval num_timesteps=9225000, episode_reward=1807.00 +/- 478.25
# Episode length: 8210.80 +/- 1589.41
# Eval num_timesteps=9250000, episode_reward=1487.00 +/- 657.38
# Episode length: 6426.00 +/- 2512.20
# Eval num_timesteps=9275000, episode_reward=1583.00 +/- 642.73
# Episode length: 7525.80 +/- 1974.59
# Eval num_timesteps=9300000, episode_reward=1530.00 +/- 364.44
# Episode length: 7356.00 +/- 1406.41
# Eval num_timesteps=9325000, episode_reward=1543.00 +/- 415.70
# Episode length: 7648.80 +/- 1881.12
# Eval num_timesteps=9350000, episode_reward=1325.00 +/- 545.10
# Episode length: 6387.20 +/- 1963.84
# Eval num_timesteps=9375000, episode_reward=1289.00 +/- 198.53
# Episode length: 6539.80 +/- 1011.93
# Eval num_timesteps=9400000, episode_reward=1168.00 +/- 199.04
# Episode length: 5756.40 +/- 700.21
# Eval num_timesteps=9425000, episode_reward=945.00 +/- 495.48
# Episode length: 5071.20 +/- 2852.19
# Eval num_timesteps=9450000, episode_reward=1303.00 +/- 272.85
# Episode length: 6400.40 +/- 1224.25
# Eval num_timesteps=9475000, episode_reward=1294.00 +/- 600.87
# Episode length: 6211.20 +/- 2731.82
# Eval num_timesteps=9500000, episode_reward=762.00 +/- 246.24
# Episode length: 4277.00 +/- 1231.36
# Eval num_timesteps=9525000, episode_reward=1265.00 +/- 409.23
# Episode length: 6013.40 +/- 1122.87
# Eval num_timesteps=9550000, episode_reward=1775.00 +/- 692.90
# Episode length: 7718.00 +/- 2698.99
# Eval num_timesteps=9575000, episode_reward=1474.00 +/- 273.38
# Episode length: 7052.20 +/- 1267.87
# Eval num_timesteps=9600000, episode_reward=1020.00 +/- 529.63
# Episode length: 4824.20 +/- 2472.88
# Eval num_timesteps=9625000, episode_reward=1525.00 +/- 375.43
# Episode length: 7087.80 +/- 1384.94
# Eval num_timesteps=9650000, episode_reward=760.00 +/- 330.80
# Episode length: 3614.40 +/- 1488.54
# Eval num_timesteps=9675000, episode_reward=1818.00 +/- 410.21
# Episode length: 8343.20 +/- 1934.97
# Eval num_timesteps=9700000, episode_reward=1283.00 +/- 463.51
# Episode length: 6370.80 +/- 1905.72
# Eval num_timesteps=9725000, episode_reward=1358.00 +/- 712.62
# Episode length: 6605.20 +/- 2848.53
# Eval num_timesteps=9750000, episode_reward=822.00 +/- 356.45
# Episode length: 4448.80 +/- 1469.95
# Eval num_timesteps=9775000, episode_reward=1111.00 +/- 385.06
# Episode length: 5422.40 +/- 1677.09
# Eval num_timesteps=9800000, episode_reward=1787.00 +/- 877.99
# Episode length: 7751.20 +/- 3629.21
# Eval num_timesteps=9825000, episode_reward=1552.00 +/- 568.34
# Episode length: 7098.00 +/- 2299.97
# Eval num_timesteps=9850000, episode_reward=1374.00 +/- 591.93
# Episode length: 6229.80 +/- 2341.13
# Eval num_timesteps=9875000, episode_reward=1764.00 +/- 526.86
# Episode length: 8590.60 +/- 2492.14
# Eval num_timesteps=9900000, episode_reward=1423.00 +/- 292.00
# Episode length: 6895.00 +/- 1379.97
# Eval num_timesteps=9925000, episode_reward=1365.00 +/- 216.79
# Episode length: 6592.00 +/- 1164.63
# Eval num_timesteps=9950000, episode_reward=1226.00 +/- 561.53
# Episode length: 5793.60 +/- 2228.84
# Eval num_timesteps=9975000, episode_reward=1294.00 +/- 636.48
# Episode length: 6004.00 +/- 2992.66
# Eval num_timesteps=10000000, episode_reward=873.00 +/- 285.53
# Episode length: 4786.40 +/- 1253.69
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_5

# %% [markdown]
# #### Solution

# %%
# !python train.py --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python enjoy.py  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=5
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_5/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 1120.00
# Atari Episode Length 6112
# Atari Episode Score: 525.00
# Atari Episode Length 2679
# Atari Episode Score: 2205.00
# Atari Episode Length 8728

# %% [markdown]
# #### Solution

# %%
# !python enjoy.py  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub.py` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga bitcloud2 -f logs/
# Out:
# Loading latest experiment, id=5
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_5/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Uploading to bitcloud2/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /OpenMail/hf_rl_class/unit3/rl-baselines3-zoo/hub/dqn-SpaceInvadersNoFrameskip-v4 is already a clone of https://huggingface.co/bitcloud2/dqn-SpaceInvadersNoFrameskip-v4. Make sure you pull the latest changes with `repo.git_pull()`.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpz6tahicy/-step-0-to-step-1000.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpz6tahicy/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.37, start: 0.000000, bitrate: 46 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 43 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b38d5a8cc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b38d5a8cc0] profile High, level 1.2
# [libx264 @ 0x55b38d5a8cc0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/dqn-SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 160x210, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1001 fps=0.0 q=-1.0 Lsize=     188kB time=00:00:33.26 bitrate=  46.3kbits/s speed=84.2x
# video:176kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.910219%
# [libx264 @ 0x55b38d5a8cc0] frame I:5     Avg QP:16.71  size:  3393
# [libx264 @ 0x55b38d5a8cc0] frame P:314   Avg QP:23.24  size:   405
# [libx264 @ 0x55b38d5a8cc0] frame B:682   Avg QP:30.04  size:    52
# [libx264 @ 0x55b38d5a8cc0] consecutive B-frames:  4.7%  9.8% 10.8% 74.7%
# [libx264 @ 0x55b38d5a8cc0] mb I  I16..4: 15.0% 41.0% 44.0%
# [libx264 @ 0x55b38d5a8cc0] mb P  I16..4:  0.5%  1.1%  1.1%  P16..4:  8.4%  2.9%  1.9%  0.0%  0.0%    skip:84.0%
# [libx264 @ 0x55b38d5a8cc0] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8:  9.3%  0.6%  0.1%  direct: 0.1%  skip:89.6%  L0:48.2% L1:51.5% BI: 0.2%
# [libx264 @ 0x55b38d5a8cc0] 8x8 transform intra:38.9% inter:5.4%
# [libx264 @ 0x55b38d5a8cc0] coded y,uvDC,uvAC intra: 25.4% 40.7% 38.2% inter: 1.2% 1.4% 1.2%
# [libx264 @ 0x55b38d5a8cc0] i16 v,h,dc,p: 33% 61%  6%  0%
# [libx264 @ 0x55b38d5a8cc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30%  9% 60%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x55b38d5a8cc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 12% 38%  2%  2%  3%  1%  3%  1%
# [libx264 @ 0x55b38d5a8cc0] i8c dc,h,v,p: 55% 31% 13%  1%
# [libx264 @ 0x55b38d5a8cc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55b38d5a8cc0] ref P L0: 68.0%  5.3% 11.5% 15.3%
# [libx264 @ 0x55b38d5a8cc0] ref B L0: 80.4% 16.2%  3.4%
# [libx264 @ 0x55b38d5a8cc0] ref B L1: 95.1%  4.9%
# [libx264 @ 0x55b38d5a8cc0] kb/s:43.02
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   1%| | 224k/26.0M [00:01<02:17
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0%| | 32.0k/12.9M [00:
#
# Upload file replay.mp4:  17%|███▉                   | 32.0k/188k [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%| | 32.0k/
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  41%|▍| 10.6M/26.0M [00:02<00:0
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  62%|▌| 7.94M/12.9M [00:
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  91%|▉| 23.7M/26.0M [00:03<00:0remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/bitcloud2/dqn-SpaceInvadersNoFrameskip-v4
#    e244954..f73d1f9  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 26.0M/26.0M [00:05<00:0
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|█| 12.9M/12.9M [00:
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|█| 12.9M/12.9M [00:
#
#
# Upload file replay.mp4: 100%|████████████████| 188k/188k [00:04<00:00, 39.8kB/s]
#
# Upload file replay.mp4: 100%|████████████████| 188k/188k [00:04<00:00, 39.8kB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|█| 12.9M/
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|█| 12.9M/
#
#
#
#
# Upload file train_eval_metrics.zip: 100%|████| 266k/266k [00:04<00:00, 59.8kB/s]
#
#
#
# Upload file train_eval_metrics.zip: 100%|████| 266k/266k [00:04<00:00, 59.8kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/bitcloud2/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python enjoy.py --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
